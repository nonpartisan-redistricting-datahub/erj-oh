# %%
import pandas as pd
import geopandas as gp
import numpy as np 
import os
import fiona
from statistics import mean, median
import string
import re
from collections import Counter

# %% [markdown]
# # VEST OH 2020
# ---

# %% [markdown]
# ## VEST Documentation

# %% [markdown]
# ### Election Results
#
# #### Sources
# Election results from the Ohio Secretary of State (https://www.sos.state.oh.us/elections/election-results-and-data/).
#
# #### Processing Part 1
# The following counties include adjustments to account for corporate annexations that are not specified below by precinct: Adams, Athens, Butler, Franklin, Guernsey, Montgomery, Stark, Tuscarawas, Warren, Wayne.
#
# #### Processing Part 2 (unclear whether this is for election results, shapefiles, or both)
# The following additional revisions were made to match the 2020 precinct boundaries:
#
# - **Athens:** Adjust Athens 4-4/4-5, Nelsonville 1/2/3/4
# - **Brown:** Adjust Perry Twp South/Villages
# - **Butler:** Adjust Hamilton 22/24, Oxford 6/11, Trenton 5/7, West Chester 28/39
# - **Champaign:** Adjust Union N/S
# - **Clark:** Align New Carlisle, Springfield precincts with county maps
# - **Crawford:** Move eastern Polk Twp from Galion 1B to western Polk Twp
# - **Cuyahoga:** Adjust Olmsted Twp D/F/H
# - **Delaware:** Adjust Berlin C/Delaware 3-F
# - **Fairfield:** Adjust Greenfield B/Lancaster 2-A, Pickerington F/Violet B/Violet C
# - **Greene:** Adjust Bath 277/Fairborn 226/Xenia 351
# - **Hamilton:** Adjust Cleves A/Whitewater A, Colerain BB/F
# - **Knox:** Adjust Clinton A/Mount Vernon 1-B, Clinton B/Mount Vernon 2-A
# - **Lake:** Adjust Painesville A/K
# - **Medina:** Adjust Wadsworth City 1-D/Sharon D, Wadsworth City 2-D/Twp C
# - **Richland:** Adjust Ontario 3/4
# - **Stark:** Adjust Canton 8-C/Plain 6, Canton 6-A/Plain 12
# - **Summit:** Adjust Coventry D/G, Hudson 1-B/3-C, Springfield F/J
# - **Warren:** Adjust Mason City Z/Union A, South Lebanon A/B
#
# #### Races
# G20PRERTRU - Donald J. Trump (Republican Party)
# G20PREDBID - Joseph R. Biden (Democratic Party)
# G20PRELJOR - Jo Jorgensen (Libertarian Party)
# G20PREGHAW - Howie Hawkins (Independent)

# %% [markdown]
# ### Shapefiles
#
# #### Sources
# Precinct shapefile from the U.S. Census Bureau's 2020 Redistricting Data Program final release. Note that some VTDs were relabeled to match precinct names and/or precinct codes in the November 2020 general election returns.

# %% [markdown]
# # Election Result Processing

# %% [markdown]
# ## Get VEST file and FIPS dictionary ready

# %% [markdown]
# ### Load in VEST file

# %%
vest_oh_20 = gp.read_file("./raw-from-source/VEST/oh_2020/oh_2020.shp")

# %%
vest_oh_20.crs
# Out:
# <Geographic 2D CRS: EPSG:4269>
# Name: NAD83
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: North America - onshore and offshore: Canada - Alberta; British Columbia; Manitoba; New Brunswick; Newfoundland and Labrador; Northwest Territories; Nova Scotia; Nunavut; Ontario; Prince Edward Island; Quebec; Saskatchewan; Yukon. Puerto Rico. United States (USA) - Alabama; Alaska; Arizona; Arkansas; California; Colorado; Connecticut; Delaware; Florida; Georgia; Hawaii; Idaho; Illinois; Indiana; Iowa; Kansas; Kentucky; Louisiana; Maine; Maryland; Massachusetts; Michigan; Minnesota; Mississippi; Missouri; Montana; Nebraska; Nevada; New Hampshire; New Jersey; New Mexico; New York; North Carolina; North Dakota; Ohio; Oklahoma; Oregon; Pennsylvania; Rhode Island; South Carolina; South Dakota; Tennessee; Texas; Utah; Vermont; Virginia; Washington; West Virginia; Wisconsin; Wyoming. US Virgin Islands. British Virgin Islands.
# - bounds: (167.65071105957, 14.928194130078, -47.743430543984, 86.453745196084)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
vest_oh_20.boundary.plot()
# Out:
# <AxesSubplot:>

# %%
vest_oh_20.columns
# Out:
# Index(['STATEFP20', 'COUNTYFP20', 'VTDST20', 'PRECINCT20', 'GEOID20', 'NAME20',
#        'G20PRERTRU', 'G20PREDBID', 'G20PRELJOR', 'G20PREGHAW', 'geometry'],
#       dtype='object')

# %% [markdown]
# ### Create a FIPs dictionary for OH

# %%
#Load in the nationwide FIPS file
fips_file = pd.read_csv("./raw-from-source/FIPS/US_FIPS_Codes.csv")
fips_file = fips_file[fips_file["State"]=="Ohio"]
fips_file["FIPS County"]=fips_file["FIPS County"].astype(str)

#Make the FIPS three digits
fips_file["FIPS County"]=fips_file["FIPS County"].str.zfill(3)

#Create the dictionary
oh_fips_dict = dict(zip(fips_file["County Name"],fips_file["FIPS County"]))

# %% [markdown]
# ## Load and Clean Election Results

# %% [markdown]
# ### Load Election Results

# %% [markdown]
# Cleaned the `statewideresultsbyprecinct.xlsx` file by hand, and created `statewideresultsbyprecinct_clean.csv`. No modifications were made to the election results. Unnecessary tabs were removed and column names were renamed to match VEST's manually.

# %%
#Load in clean SOS file
dem_elections_2020 = pd.read_excel("./raw-from-source/SOS/democratprecinctall.xlsx",sheet_name="Master")
rep_elections_2020 = pd.read_excel("./raw-from-source/SOS/republicanprecinct.xlsx",sheet_name="Master")
lib_elections_2020 = pd.read_excel("./raw-from-source/SOS/libertarianprecinctall.xlsx",sheet_name="Master")

# %%
dem_elections_2020.head()
# Out:
#   March 17, 2020 Primary Election Official Canvass\n*Results for write-in (WI) candidates will not be available on election night.\n*Write-in candidates will be displayed with a (WI) designation and not party affiliation.\n*Precinct-level data is not available for write-in candidates. To view results for write-in candidates, download the Summary-level spreadsheet.  \
# 0                                        County Name
# 1                                              Total
# 2                                         Percentage
# 3                                              Adams
# 4                                              Adams
#
#              Unnamed: 1     Unnamed: 2   Unnamed: 3    Unnamed: 4  \
# 0         Precinct Name  Precinct Code  Region Name  Media Market
# 1                   NaN            NaN          NaN           NaN
# 2                   NaN            NaN          NaN           NaN
# 3      BRATTON TOWNSHIP            AAA    Southwest    Cincinnati
# 4  BRUSH CREEK TOWNSHIP            AAB    Southwest    Cincinnati
#
#           Unnamed: 5    Unnamed: 6          Unnamed: 7 President (at-large)\n  \
# 0  Registered Voters  Total Voters  Turnout Percentage     Michael Bennet (D)
# 1            7774767       1834465            0.235951                   2030
# 2                NaN           NaN                 NaN               0.002271
# 3                904           241            0.266593                      0
# 4                749           183            0.244326                      0
#
#                Unnamed: 9  ... State Representative - District 88\n  \
# 0  Joseph R. Biden Jr (D)  ...                    Chris Liebold (D)
# 1                  647284  ...                                 5473
# 2                0.724128  ...                                    1
# 3                      42  ...                                    0
# 4                      36  ...                                    0
#
#   State Representative - District 89\n State Representative - District 91\n  \
# 0                    Alexis Miller (D)                  Scott M. Dailey (D)
# 1                                 7769                                 3225
# 2                                    1                                    1
# 3                                    0                                    0
# 4                                    0                                    0
#
#   State Representative - District 92\n State Representative - District 94\n  \
# 0                     Beth Workman (D)                    Katie O'Neill (D)
# 1                                 4669                                 5356
# 2                                    1                                    1
# 3                                    0                                    0
# 4                                    0                                    0
#
#   State Representative - District 96\n            Unnamed: 193  \
# 0                  Charlie DiPalma (D)  Richard A. Olivito (D)
# 1                                 4359                    5370
# 2                             0.448042                0.551958
# 3                                    0                       0
# 4                                    0                       0
#
#   State Representative - District 97\n State Representative - District 98\n  \
# 0                     Alaina Swope (D)                    Todd E Beegle (D)
# 1                                 4139                                 4870
# 2                                    1                                    1
# 3                                    0                                    0
# 4                                    0                                    0
#
#   State Representative - District 99\n
# 0                     Richard Dana (D)
# 1                                 5836
# 2                                    1
# 3                                    0
# 4                                    0
#
# [5 rows x 197 columns]

# %%
def clean_oh_import(dataframe):
    
    corrected_col_names = []
    for index in range(0,len(dataframe.columns)):
        col_name = dataframe.columns[index]
        col_name = col_name.replace("\n"," ")
        if "Unnamed" in col_name:
            corrected_col_names.append(corrected_col_names[index-1])
        else:
            corrected_col_names.append(col_name)
    dataframe.columns = corrected_col_names
    
    corrected_col_names = []
    for index in range(0,len(dataframe.columns)):
        col = dataframe.columns[index]
        first_row = dataframe.iloc[0,index]
        if (index > 7):
            new_column_name = col + " " + first_row 
            corrected_col_names.append(new_column_name)
        else:
            corrected_col_names.append(first_row)
    dataframe.columns = corrected_col_names
    
    dataframe = dataframe.iloc[3:,]
    return dataframe

# %%
dem_elections_2020_clean = clean_oh_import(dem_elections_2020)
rep_elections_2020_clean = clean_oh_import(rep_elections_2020)
lib_elections_2020_clean = clean_oh_import(lib_elections_2020)

# %%
for val in [dem_elections_2020_clean,rep_elections_2020_clean,lib_elections_2020_clean]:
    print(val.shape)
    val["UNIQUE_ID"] = val["County Name"]+"-"+val["Precinct Code"]
# Out:
# (8933, 197)
# (8933, 226)
# (8933, 15)
# <ipython-input-11-e60a347620bc>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val["UNIQUE_ID"] = val["County Name"]+"-"+val["Precinct Code"]

# %%
col_check_1 = rep_elections_2020_clean["UNIQUE_ID"] == lib_elections_2020_clean["UNIQUE_ID"]
col_check_2 = lib_elections_2020_clean["UNIQUE_ID"] == dem_elections_2020_clean["UNIQUE_ID"]

# %%
rep_elections_2020_clean.columns
# Out:
# Index(['County Name', 'Precinct Name', 'Precinct Code', 'Region Name',
#        'Media Market', 'Registered Voters', 'Total Voters',
#        'Turnout Percentage', 'President (at-large)  Donald J. Trump (R)',
#        'President (district) - District 01  Donald J. Trump (R)',
#        ...
#        'State Representative - District 92  Mark Johnson (R)',
#        'State Representative - District 93  Jeff Halley (R)',
#        'State Representative - District 93  Jason C. Stephens (R)',
#        'State Representative - District 94  Jay Edwards (R)',
#        'State Representative - District 95  Don Jones (R)',
#        'State Representative - District 96  Ron Ferguson (R)',
#        'State Representative - District 97  Adam Holmes (R)',
#        'State Representative - District 98  Brett Hudson Hillyer (R)',
#        'State Representative - District 99  Sarah E. Fowler (R)', 'UNIQUE_ID'],
#       dtype='object', length=227)

# %%
rep_elections_2020_clean.drop(['County Name', 'Precinct Name', 'Precinct Code', 'Region Name','Media Market', 'Registered Voters','Total Voters','Turnout Percentage',"UNIQUE_ID"],inplace=True,axis=1)
lib_elections_2020_clean.drop(['County Name', 'Precinct Name', 'Precinct Code', 'Region Name','Media Market', 'Registered Voters','Total Voters','Turnout Percentage',"UNIQUE_ID"],inplace=True,axis=1)
# Out:
# /Users/peterhorton/opt/anaconda3/envs/geo_env/lib/python3.9/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
combined = pd.concat([dem_elections_2020_clean,rep_elections_2020_clean,lib_elections_2020_clean],axis=1)

# %%
elections_2020 = combined.copy(deep=True)

# %%
elections_2020.drop("UNIQUE_ID", axis=1 , inplace=True)

# %%
#Map to the correct FIP
elections_2020["COUNTYFP"]=elections_2020["County Name"].map(oh_fips_dict).fillna(elections_2020["County Name"])

#Print out the FIPS to make sure they all are in the correct format
elections_2020["COUNTYFP"].unique()
# Out:
# array(['001', '003', '005', '007', '009', '011', '013', '015', '017',
#        '019', '021', '023', '025', '027', '029', '031', '033', '035',
#        '037', '039', '041', '043', '045', '047', '049', '051', '053',
#        '055', '057', '059', '061', '063', '065', '067', '069', '071',
#        '073', '075', '077', '079', '081', '083', '085', '087', '089',
#        '091', '093', '095', '097', '099', '101', '103', '105', '107',
#        '109', '111', '113', '115', '117', '119', '121', '123', '125',
#        '127', '129', '131', '133', '135', '137', '139', '141', '143',
#        '145', '147', '149', '151', '153', '155', '157', '159', '161',
#        '163', '165', '167', '169', '171', '173', '175'], dtype=object)

# %%
filter_out_cols = [i for i in elections_2020.columns if ("Judge of the Court of Appeals - District" in i or "Member of the State Board of Education - District" in i or "WI" in i)]

# %%
elections_2020 = elections_2020[[i for i in elections_2020.columns if i not in filter_out_cols]]

# %% [markdown]
# ## Look into split precincts

# %%
def get_level_dist(column_name):
    if "Representative to Congress" in column_name:
        level = "CON"
    elif "State Senator" in column_name:
        level = "SU"
    elif "State Representative" in column_name:
        level = "SL"
    else:
        raise ValueError
    return_val = re.findall("District \S{2}",column_name)    
    if (len(return_val)!=0):
        dist = return_val[0].split(" ")[1]
    else:
        raise ValueError
    return level,dist

# %%
def is_split_precinct(district_assignment_list):
    c = Counter([x[0] for x in district_assignment_list])
    greater_than_one = {x:[y[1] for y in district_assignment_list if y[0]==x] for x, count in c.items() if count > 1}
    if len(greater_than_one)==0:
        return 0
    else:
        return greater_than_one

# %%
for col in elections_2020[[i for i in elections_2020.columns if "President (district)" in i]]:
    print(col)
    print(sum(elections_2020[[i for i in elections_2020.columns if "President" in i]][col]))
# Out:
# President (district) - District 01  Donald J. Trump (R)
# 45125
# President (district) - District 02  Donald J. Trump (R)
# 52981
# President (district) - District 03  Donald J. Trump (R)
# 12971
# President (district) - District 04  Donald J. Trump (R)
# 63283
# President (district) - District 05  Donald J. Trump (R)
# 56297
# President (district) - District 06  Donald J. Trump (R)
# 62299
# President (district) - District 07  Donald J. Trump (R)
# 54886
# President (district) - District 08  Donald J. Trump (R)
# 56470
# President (district) - District 09  Donald J. Trump (R)
# 18095
# President (district) - District 10  Donald J. Trump (R)
# 47061
# President (district) - District 11  Donald J. Trump (R)
# 10116
# President (district) - District 12  Donald J. Trump (R)
# 56368
# President (district) - District 13  Donald J. Trump (R)
# 29243
# President (district) - District 14  Donald J. Trump (R)
# 49125
# President (district) - District 15  Donald J. Trump (R)
# 43236
# President (district) - District 16  Donald J. Trump (R)
# 43543

# %%
#Combine the republican presidential primary results into one column
elections_2020["President Donald J. Trump (R)"] = 0
for val in [i for i in elections_2020.columns if "President (district)" in i]:
    elections_2020["President Donald J. Trump (R)"] += elections_2020[val]

# %%
elections_2020.drop([i for i in elections_2020.columns if "President (district)" in i],axis=1,inplace=True)

# %%
district_cols = [i for i in elections_2020.columns if "District" in i]
elections_2020_districts = elections_2020[['COUNTYFP','Precinct Name','Precinct Code']+district_cols]

# %%
precinct_mapping_dict = {}
split_precincts_list = {}
for index,row in elections_2020_districts.iterrows():
    precinct_list = []
    for contest in district_cols:
        if(row[contest]!=0):
            precinct_info = get_level_dist(contest)
            if precinct_info not in precinct_list:
                precinct_list.append(get_level_dist(contest))
    is_split = is_split_precinct(precinct_list)
    if (is_split):
        split_precincts_list[row["COUNTYFP"]+"-"+row["Precinct Code"]]=is_split
    precinct_mapping_dict[row["COUNTYFP"]+"-"+row["Precinct Code"]]=precinct_list

# %% [markdown]
# ## Rename the columns

# %%
list(elections_2020.columns)
# Out:
# ['County Name',
#  'Precinct Name',
#  'Precinct Code',
#  'Region Name',
#  'Media Market',
#  'Registered Voters',
#  'Total Voters',
#  'Turnout Percentage',
#  'President (at-large)  Michael Bennet (D)',
#  'President (at-large)  Joseph R. Biden Jr (D)',
#  'President (at-large)  Michael R.  Bloomberg (D)',
#  'President (at-large)  Pete Buttigieg (D)',
#  'President (at-large)  Tulsi Gabbard (D)',
#  'President (at-large)  Amy  Klobuchar (D)',
#  'President (at-large)  Deval Patrick (D)',
#  'President (at-large)  Bernie Sanders (D)',
#  'President (at-large)  Tom Steyer (D)',
#  'President (at-large)  Elizabeth Warren (D)',
#  'Representative to Congress - District 01  Nikki Foster (D)',
#  'Representative to Congress - District 01  Kate Schroder (D)',
#  'Representative to Congress - District 02  Jaime M. Castle (D)',
#  'Representative to Congress - District 03  Joyce Beatty (D)',
#  'Representative to Congress - District 03  Morgan Harper (D)',
#  'Representative to Congress - District 04  Shannon M. Freshour (D)',
#  'Representative to Congress - District 04  Mike Larsen (D)',
#  'Representative to Congress - District 04  Jeffrey A. Sites (D)',
#  'Representative to Congress - District 05  M. Xavier Carrigan (D)',
#  'Representative to Congress - District 05  Gene Redinger (D)',
#  'Representative to Congress - District 05  Nick Rubando (D)',
#  'Representative to Congress - District 06  Shawna Roberts (D)',
#  'Representative to Congress - District 08  Vanessa Enoch (D)',
#  'Representative to Congress - District 08  Matt Guyette (D)',
#  'Representative to Congress - District 09  Marcy Kaptur (D)',
#  'Representative to Congress - District 09  Peter Rosewicz (D)',
#  'Representative to Congress - District 10  Eric Moyer (D)',
#  'Representative to Congress - District 10  Desiree Tims (D)',
#  'Representative to Congress - District 11  James Jerome Bell (D)',
#  'Representative to Congress - District 11  Marcia L. Fudge (D)',
#  'Representative to Congress - District 11  Michael Hood (D)',
#  'Representative to Congress - District 11  Tariq K. Shabazz (D)',
#  'Representative to Congress - District 12  Jenny Bell (D)',
#  'Representative to Congress - District 12  Alaina Shearer (D)',
#  'Representative to Congress - District 13  Tim Ryan (D)',
#  "Representative to Congress - District 14  Hillary O'Connor Mueri (D)",
#  'Representative to Congress - District 15  Daniel McArthur Kilgore (D)',
#  'Representative to Congress - District 15  Joel Newby (D)',
#  'Representative to Congress - District 16  Aaron Paul Godfrey (D)',
#  'Representative to Congress - District 16  Ronald Karpus III (D)',
#  "Justice of the Supreme Court Term Commencing 01/01/2021 John P. O'Donnell (D)",
#  'Justice of the Supreme Court Term Commencing 01/02/2021 Jennifer Brunner (D)',
#  "State Senator - District 02  Joel O'Dorisio (D)",
#  'State Senator - District 02  Reem Subei (D)',
#  'State Senator - District 04  Kathy Wyenandt (D)',
#  'State Senator - District 06  Mark Fogel (D)',
#  'State Senator - District 06  Albert Griggs Jr (D)',
#  'State Senator - District 08  Daniel Brown (D)',
#  'State Senator - District 10  Charles Ballard (D)',
#  'State Senator - District 12  Ken Poling (D)',
#  'State Senator - District 14  Ryan Ottney (D)',
#  'State Senator - District 16  Mark L. Bailey (D)',
#  'State Senator - District 16  Troy Doucet (D)',
#  'State Senator - District 16  Crystal Lett (D)',
#  'State Senator - District 18  Betsy Rader (D)',
#  'State Senator - District 20  Christian N. Johnson (D)',
#  'State Senator - District 22  Steve Johnson (D)',
#  'State Senator - District 24  Tom Jackson (D)',
#  'State Senator - District 26  Craig Swartz (D)',
#  'State Senator - District 28  Vernon Sykes (D)',
#  'State Senator - District 30  Michael Fletcher (D)',
#  "State Senator - District 32  Sean J. O'Brien (D)",
#  'State Representative - District 01  Alison Theiss (D)',
#  'State Representative - District 03  Laurel Johnson (D)',
#  'State Representative - District 05  Daniel Winston (D)',
#  'State Representative - District 06  Phil Robinson (D)',
#  'State Representative - District 07  Joan T. Sweeny (D)',
#  'State Representative - District 08  Kent Smith (D)',
#  'State Representative - District 09  Janine Boyd (D)',
#  'State Representative - District 09  Vincent E. Stokes II (D)',
#  'State Representative - District 10  J. Allen Burger (D)',
#  'State Representative - District 10  Terrence Upchurch (D)',
#  'State Representative - District 11  Stephanie Howse (D)',
#  'State Representative - District 12  Juanita Brent (D)',
#  'State Representative - District 12  Felicia Washington Ross (D)',
#  'State Representative - District 13  Michael J. Skindell (D)',
#  'State Representative - District 14  Bride Rose Sweeney (D)',
#  'State Representative - District 15  Jeffrey A. Crossman (D)',
#  'State Representative - District 16  Joe Romano (D)',
#  'State Representative - District 16  Monique Smith (D)',
#  'State Representative - District 17  Adam C. Miller (D)',
#  'State Representative - District 18  Kristin Boggs (D)',
#  'State Representative - District 19  Mary Lightbody (D)',
#  'State Representative - District 20  Richard Brown (D)',
#  'State Representative - District 21  Beth Liston (D)',
#  'State Representative - District 22  Kashi Adhikari (D)',
#  'State Representative - District 22  David Leland (D)',
#  'State Representative - District 23  Nancy Day-Achauer (D)',
#  'State Representative - District 24  Allison Russo (D)',
#  'State Representative - District 25  Mohamud Jama (D)',
#  'State Representative - District 25  Dontavius Jarrells (D)',
#  'State Representative - District 25  Gary Josephson (D)',
#  'State Representative - District 25  Mayo Makinde (D)',
#  'State Representative - District 25  Kofi Nsia-Pepra (D)',
#  'State Representative - District 26  Erica C. Crawley (D)',
#  'State Representative - District 27  Sara Bitter (D)',
#  'State Representative - District 28  Jessica E. Miranda (D)',
#  'State Representative - District 31  Brigid Kelly (D)',
#  'State Representative - District 32  Catherine D. Ingram (D)',
#  'State Representative - District 32  Dadrien Washington (D)',
#  'State Representative - District 33  Sedrick Denson (D)',
#  'State Representative - District 33  Terence Allen Gragston (D)',
#  'State Representative - District 34  Emilia Sykes (D)',
#  'State Representative - District 35  Tavia Galonski (D)',
#  'State Representative - District 36  A. J. Harris (D)',
#  'State Representative - District 36  Matt Shaughnessy (D)',
#  'State Representative - District 37  Casey Weinstein (D)',
#  'State Representative - District 38  Joe Campbell (D)',
#  'State Representative - District 39  Willis E. Blackshear Jr (D)',
#  'State Representative - District 39  Walter J. Hickman Jr (D)',
#  "State Representative - District 39  Jo'el Jones (D)",
#  'State Representative - District 40  Leronda Jackson (D)',
#  'State Representative - District 41  Cate Berger (D)',
#  'State Representative - District 43  Amy Cox (D)',
#  'State Representative - District 45  Lisa A. Sobecki (D)',
#  'State Representative - District 46  Michael P. Sheehy (D)',
#  'State Representative - District 47  Nancy Larson (D)',
#  'State Representative - District 49  Thomas E. West (D)',
#  'State Representative - District 50  Brian K Simeone (D)',
#  'State Representative - District 52  Chuck Horn (D)',
#  'State Representative - District 53  Michelle E. Novak (D)',
#  'State Representative - District 54  Morgan Showen (D)',
#  'State Representative - District 55  Zach Stepp (D)',
#  'State Representative - District 56  Joe Miller (D)',
#  'State Representative - District 57  Dara Adkison (D)',
#  'State Representative - District 58  Michele Lepore Hagan (D)',
#  'State Representative - District 59  Chris Stanley (D)',
#  'State Representative - District 60  Daniel P. Troy (D)',
#  'State Representative - District 61  Adam Dudziak (D)',
#  'State Representative - District 62  Erin Rosiello (D)',
#  'State Representative - District 63  Gil Blair (D)',
#  'State Representative - District 63  Werner Lange (D)',
#  'State Representative - District 63  Barry Profato (D)',
#  "State Representative - District 64  Michael J. O'Brien (D)",
#  'State Representative - District 65  Alan Darnowsky (D)',
#  'State Representative - District 67  Rachael Morocco (D)',
#  'State Representative - District 68  Steven F. Mount (D)',
#  'State Representative - District 69  Donna Beheydt (D)',
#  'State Representative - District 70  Kevin Barnet (D)',
#  'State Representative - District 71  Mark Carr (D)',
#  'State Representative - District 73  Kim McCarthy (D)',
#  'State Representative - District 75  Randi Clites (D)',
#  'State Representative - District 76  Garrett Westhoven (D)',
#  'State Representative - District 77  Melissa Wilde (D)',
#  'State Representative - District 78  Charlotte Owens (D)',
#  'State Representative - District 79  Cynthia Richards (D)',
#  'State Representative - District 84  Joseph A. Monbeck (D)',
#  'State Representative - District 86  Tiffanie Roberts (D)',
#  'State Representative - District 87  Nicholas Barnes (D)',
#  'State Representative - District 88  Chris Liebold (D)',
#  'State Representative - District 89  Alexis Miller (D)',
#  'State Representative - District 91  Scott M. Dailey (D)',
#  'State Representative - District 92  Beth Workman (D)',
#  "State Representative - District 94  Katie O'Neill (D)",
#  'State Representative - District 96  Charlie DiPalma (D)',
#  'State Representative - District 96  Richard A. Olivito (D)',
#  'State Representative - District 97  Alaina Swope (D)',
#  'State Representative - District 98  Todd E Beegle (D)',
#  'State Representative - District 99  Richard Dana (D)',
#  'President (at-large)  Donald J. Trump (R)',
#  'Representative to Congress - District 01  Steve Chabot (R)',
#  'Representative to Congress - District 02  H. Robert Harris (R)',
#  'Representative to Congress - District 02  Brad Wenstrup (R)',
#  'Representative to Congress - District 03  Cleophus Dulaney (R)',
#  'Representative to Congress - District 03  Mark F. Richardson (R)',
#  'Representative to Congress - District 04  Jim Jordan (R)',
#  'Representative to Congress - District 05  Bob Latta (R)',
#  'Representative to Congress - District 06  Bill Johnson (R)',
#  'Representative to Congress - District 06  Kenneth Morgan (R)',
#  'Representative to Congress - District 07  Bob Gibbs (R)',
#  'Representative to Congress - District 08  Warren Davidson (R)',
#  'Representative to Congress - District 08  Edward R. Meer (R)',
#  'Representative to Congress - District 09  Charles W. Barrett (R)',
#  'Representative to Congress - District 09  Tim Connors (R)',
#  'Representative to Congress - District 09  Timothy P. Corrigan (R)',
#  'Representative to Congress - District 09  Rob Weber (R)',
#  'Representative to Congress - District 10  John Anderson (R)',
#  'Representative to Congress - District 10  Kathi Flanders (R)',
#  'Representative to Congress - District 10  Mike Turner (R)',
#  'Representative to Congress - District 11  Laverne Gore (R)',
#  'Representative to Congress - District 11  Jonah Schulz (R)',
#  'Representative to Congress - District 11  Shalira Taylor (R)',
#  'Representative to Congress - District 12  Troy Balderson (R)',
#  'Representative to Congress - District 12  Tim Day (R)',
#  'Representative to Congress - District 13  Christina M. Hagan (R)',
#  'Representative to Congress - District 13  Duane Hennen (R)',
#  'Representative to Congress - District 13  Louis G. Lyras (R)',
#  'Representative to Congress - District 13  Richard A. Morckel (R)',
#  'Representative to Congress - District 13  Jason Mormando (R)',
#  'Representative to Congress - District 13  Robert J. Santos (R)',
#  'Representative to Congress - District 13  Donald Truex (R)',
#  'Representative to Congress - District 14  David P. Joyce (R)',
#  'Representative to Congress - District 14  Mark Pitrone (R)',
#  'Representative to Congress - District 15  Shelby Xavier Hunt (R)',
#  'Representative to Congress - District 15  Steve Stivers (R)',
#  'Representative to Congress - District 16  Anthony Gonzalez (R)',
#  'Justice of the Supreme Court Term Commencing 01/01/2021 Sharon L. Kennedy (R)',
#  'Justice of the Supreme Court Term Commencing 01/02/2021 Judi French (R)',
#  'State Senator - District 02  Theresa Gavarone (R)',
#  'State Senator - District 04  Candice Keller (R)',
#  'State Senator - District 04  George F. Lang (R)',
#  'State Senator - District 04  Lee Wong (R)',
#  'State Senator - District 06  Niraj Antani (R)',
#  'State Senator - District 06  Gregory Alan Robinson (R)',
#  'State Senator - District 06  Rachel Selby (R)',
#  'State Senator - District 08  Louis W. Blessing III (R)',
#  'State Senator - District 10  Robert D. Hackett (R)',
#  'State Senator - District 12  Matt Huffman (R)',
#  'State Senator - District 14  Terry A. Johnson (R)',
#  'State Senator - District 14  David Uible (R)',
#  'State Senator - District 16  Stephanie L. Kunze (R)',
#  'State Senator - District 18  Jerry Cirino (R)',
#  'State Senator - District 20  Tim Schaffer (R)',
#  'State Senator - District 22  Cory T. Branham (R)',
#  'State Senator - District 22  Ron Falconi (R)',
#  'State Senator - District 22  Timothy Hoven (R)',
#  'State Senator - District 22  Michael Reynolds (R)',
#  'State Senator - District 22  Mark Romanchuk (R)',
#  'State Senator - District 24  Matt Dolan (R)',
#  'State Senator - District 26  Melissa Ackison (R)',
#  'State Senator - District 26  Bill Reineke (R)',
#  'State Senator - District 28  Michael Downey (R)',
#  'State Senator - District 30  Frank Hoagland (R)',
#  "State Senator - District 32  Sandra O'Brien (R)",
#  'State Senator - District 32  Kenneth J. Polke (R)',
#  'State Representative - District 01  Jason Wetz (R)',
#  'State Representative - District 01  Scott Wiggam (R)',
#  'State Representative - District 02  Marilyn John (R)',
#  'State Representative - District 02  Nathan Martin (R)',
#  'State Representative - District 03  Haraz N. Ghanbari (R)',
#  'State Representative - District 04  Bob Cupp (R)',
#  'State Representative - District 05  Tim Ginter (R)',
#  'State Representative - District 06  Ed Hargate (R)',
#  'State Representative - District 06  Shay Hawkins (R)',
#  'State Representative - District 07  Thomas F. Patton (R)',
#  'State Representative - District 09  Dustin D. Russell (R)',
#  'State Representative - District 14  Lynn McMahan (R)',
#  'State Representative - District 15  Kevin C. Kussmaul (R)',
#  'State Representative - District 16  Dave Greenspan (R)',
#  'State Representative - District 17  Tim D. Haske (R)',
#  'State Representative - District 17  John PM Rutan (R)',
#  'State Representative - District 18  Kayla Anne Packard (R)',
#  'State Representative - District 19  Meredith Freedhoff (R)',
#  'State Representative - District 20  Chris Baer (R)',
#  'State Representative - District 21  Mehek Cooke (R)',
#  'State Representative - District 22  Stephany Spencer (R)',
#  'State Representative - District 23  Laura Lanese (R)',
#  'State Representative - District 24  Pat Manley (R)',
#  'State Representative - District 25  Jim Burgess (R)',
#  'State Representative - District 27  Tom Brinkman (R)',
#  'State Representative - District 28  Chris Monzel (R)',
#  'State Representative - District 29  Cindy Abrams (R)',
#  'State Representative - District 30  Bill Seitz (R)',
#  'State Representative - District 33  Mary L. Hill (R)',
#  'State Representative - District 34  Henry Todd (R)',
#  'State Representative - District 35  Jodi Sarver (R)',
#  'State Representative - District 36  Bob Young (R)',
#  'State Representative - District 37  Beth Bigham (R)',
#  'State Representative - District 38  Bill Roemer (R)',
#  'State Representative - District 39  John Ferrell Mullins III (R)',
#  'State Representative - District 40  Phil Plummer (R)',
#  'State Representative - District 41  Andrea White (R)',
#  'State Representative - District 42  Jake Stubbs (R)',
#  'State Representative - District 42  Tom Young (R)',
#  'State Representative - District 43  Rodney Creech (R)',
#  'State Representative - District 43  J. Todd Smith (R)',
#  'State Representative - District 44  Robert McMahon (R)',
#  'State Representative - District 45  Shane Logan (R)',
#  'State Representative - District 46  Steven R. Salander (R)',
#  'State Representative - District 47  Derek Merrin (R)',
#  'State Representative - District 48  Scott Oelslager (R)',
#  'State Representative - District 49  James Haavisto (R)',
#  'State Representative - District 50  Reggie Stoltzfus (R)',
#  'State Representative - District 51  Sara P. Carruthers (R)',
#  'State Representative - District 52  Jennifer L. Gross (R)',
#  'State Representative - District 52  Mark S. Welch (R)',
#  'State Representative - District 53  Brett Guido (R)',
#  'State Representative - District 53  Thomas Hall (R)',
#  'State Representative - District 53  Diane Mullins (R)',
#  'State Representative - District 54  Paul Zeltwanger (R)',
#  'State Representative - District 55  Gayle Manning (R)',
#  'State Representative - District 56  Bradley A. Lacko (R)',
#  'State Representative - District 57  Dick Stein (R)',
#  'State Representative - District 58  David T. Simon (R)',
#  'State Representative - District 59  Don Manning (R)',
#  'State Representative - District 60  George M. Phillips (R)',
#  'State Representative - District 61  Jamie Callender (R)',
#  'State Representative - District 62  Scott Lipps (R)',
#  'State Representative - District 63  Mike Loychik (R)',
#  'State Representative - District 64  Martha Yoder (R)',
#  'State Representative - District 65  Dillon Blevins (R)',
#  'State Representative - District 65  Joe Dills (R)',
#  'State Representative - District 65  Jean Schmidt (R)',
#  'State Representative - District 66  Adam C. Bird (R)',
#  'State Representative - District 66  Allen Freeman (R)',
#  'State Representative - District 66  Nick Owens (R)',
#  'State Representative - District 67  Kris Jordan (R)',
#  'State Representative - District 68  Rick Carfagna (R)',
#  'State Representative - District 69  Sharon A. Ray (R)',
#  'State Representative - District 70  Darrell D. Kick (R)',
#  'State Representative - District 70  Terry Robertson (R)',
#  'State Representative - District 71  Thaddeus James Claggett (R)',
#  'State Representative - District 71  Mark D. Fraizer (R)',
#  'State Representative - District 72  Larry Householder (R)',
#  'State Representative - District 73  John Broughton (R)',
#  'State Representative - District 73  Brian Lampton (R)',
#  'State Representative - District 74  Bill Dean (R)',
#  'State Representative - District 75  Gail Pavliga (R)',
#  'State Representative - District 76  Diane V. Grendell (R)',
#  'State Representative - District 76  Frank Hall (R)',
#  'State Representative - District 77  Jeff LaRe (R)',
#  'State Representative - District 78  Aaron Adams (R)',
#  'State Representative - District 78  Bobby Mitchell (R)',
#  'State Representative - District 78  Brian Stewart (R)',
#  'State Representative - District 79  Kyle Koehler (R)',
#  'State Representative - District 80  Jena Powell (R)',
#  'State Representative - District 81  James M. Hoops (R)',
#  'State Representative - District 82  Craig S. Riedel (R)',
#  'State Representative - District 83  Jon Cross (R)',
#  'State Representative - District 84  Susan Manchester (R)',
#  'State Representative - District 85  Nino Vitale (R)',
#  'State Representative - District 86  Tracy Richardson (R)',
#  'State Representative - District 87  Riordan T. McClain (R)',
#  'State Representative - District 88  Gary N. Click (R)',
#  'State Representative - District 88  Ed Ollom (R)',
#  'State Representative - District 88  Shayne Thomas (R)',
#  'State Representative - District 89  D.J. Swearingen (R)',
#  'State Representative - District 90  Brian Baldridge (R)',
#  'State Representative - District 91  Shane Wilkin (R)',
#  'State Representative - District 92  Mark Johnson (R)',
#  'State Representative - District 93  Jeff Halley (R)',
#  'State Representative - District 93  Jason C. Stephens (R)',
#  'State Representative - District 94  Jay Edwards (R)',
#  'State Representative - District 95  Don Jones (R)',
#  'State Representative - District 96  Ron Ferguson (R)',
#  'State Representative - District 97  Adam Holmes (R)',
#  'State Representative - District 98  Brett Hudson Hillyer (R)',
#  'State Representative - District 99  Sarah E. Fowler (R)',
#  'Representative to Congress - District 01  Kevin David Kahn (L)',
#  'Representative to Congress - District 04  Steve Perkins (L)',
#  'Representative to Congress - District 07  Brandon Lape (L)',
#  'Representative to Congress - District 13  Michael Fricke (L)',
#  'State Representative - District 96  Oscar Herrera (L)',
#  'COUNTYFP',
#  'President Donald J. Trump (R)']

# %% [markdown]
# ## Rename Columns

# %%
elections_2020.columns

keep_names = ['County Name','Precinct Name','Precinct Code','Region Name','Media Market','Registered Voters','Ballots Counted','Official Voter Turnout','Total Voters','Turnout Percentage','COUNTYFP','UNIQUE_ID']

# %%
def get_race(contest):
    if "Justice of the Supreme Court" in contest:
        level = "SSC"
        if "Kennedy" in contest or "O'Donnell" in contest:
            level = "SSCK"
        else:
            level = "SSCF"
    elif "President" in contest:
        level = "PRE"
    elif ("Representative to Congress" in contest or "State Senator" in contest or "State Representative" in contest):
        contest_info = get_level_dist(contest)
        level = contest_info[0]+contest_info[1]
    else:
          raise ValueError
    return level

# %%
def get_party(contest):
    if contest == "State Representative - District 30  Tom Roll":
        return "I"
    if "Justice of the Supreme Court Term" in contest:
        if "Sharon L. Kennedy" in contest:
            return "R"
        elif "John P. O'Donnell" in contest:
            return "D"
        elif "Jennifer Brunner" in contest:
            return "D"
        elif "Judi French" in contest:
            return "R"
        else:
            print(contest)
            raise ValueError
    return_val = re.findall("\(\S\)",contest)   
    if (len(return_val)!=0):
        party = return_val[0][1]
        return party
    else:
        print(contest)
        raise ValueError

# %%
def get_name(contest):
    contest = contest.upper()
    contest = contest.replace("'","")
    if ("(") in contest.split(" ")[-1]:
        second_to_last = contest.split(" ")[-2]
        #second_to_last = second_to_last.replace("'","")
        if second_to_last in ["JR","III", "II"]:
            third_to_last = contest.split(" ")[-3]
            #third_to_last = third_to_last.replace("'","")
            return third_to_last[0:3]
        else:
            return second_to_last[0:3]
    else:
        return contest.split(" ")[-1][0:3]

# %%
elections_2020.drop('President Donald J. Trump (R)',axis=1,inplace=True)

# %%
contest_name_change_dict = {}
for contest in elections_2020.columns:
    if contest  not in keep_names or "President" in contest:
        contest_name_change_dict[contest] = "P"+get_race(contest)+get_party(contest)+get_name(contest)

# %%
contest_name_change_dict
# Out:
# {'President (at-large)  Michael Bennet (D)': 'PPREDBEN',
#  'President (at-large)  Joseph R. Biden Jr (D)': 'PPREDBID',
#  'President (at-large)  Michael R.  Bloomberg (D)': 'PPREDBLO',
#  'President (at-large)  Pete Buttigieg (D)': 'PPREDBUT',
#  'President (at-large)  Tulsi Gabbard (D)': 'PPREDGAB',
#  'President (at-large)  Amy  Klobuchar (D)': 'PPREDKLO',
#  'President (at-large)  Deval Patrick (D)': 'PPREDPAT',
#  'President (at-large)  Bernie Sanders (D)': 'PPREDSAN',
#  'President (at-large)  Tom Steyer (D)': 'PPREDSTE',
#  'President (at-large)  Elizabeth Warren (D)': 'PPREDWAR',
#  'Representative to Congress - District 01  Nikki Foster (D)': 'PCON01DFOS',
#  'Representative to Congress - District 01  Kate Schroder (D)': 'PCON01DSCH',
#  'Representative to Congress - District 02  Jaime M. Castle (D)': 'PCON02DCAS',
#  'Representative to Congress - District 03  Joyce Beatty (D)': 'PCON03DBEA',
#  'Representative to Congress - District 03  Morgan Harper (D)': 'PCON03DHAR',
#  'Representative to Congress - District 04  Shannon M. Freshour (D)': 'PCON04DFRE',
#  'Representative to Congress - District 04  Mike Larsen (D)': 'PCON04DLAR',
#  'Representative to Congress - District 04  Jeffrey A. Sites (D)': 'PCON04DSIT',
#  'Representative to Congress - District 05  M. Xavier Carrigan (D)': 'PCON05DCAR',
#  'Representative to Congress - District 05  Gene Redinger (D)': 'PCON05DRED',
#  'Representative to Congress - District 05  Nick Rubando (D)': 'PCON05DRUB',
#  'Representative to Congress - District 06  Shawna Roberts (D)': 'PCON06DROB',
#  'Representative to Congress - District 08  Vanessa Enoch (D)': 'PCON08DENO',
#  'Representative to Congress - District 08  Matt Guyette (D)': 'PCON08DGUY',
#  'Representative to Congress - District 09  Marcy Kaptur (D)': 'PCON09DKAP',
#  'Representative to Congress - District 09  Peter Rosewicz (D)': 'PCON09DROS',
#  'Representative to Congress - District 10  Eric Moyer (D)': 'PCON10DMOY',
#  'Representative to Congress - District 10  Desiree Tims (D)': 'PCON10DTIM',
#  'Representative to Congress - District 11  James Jerome Bell (D)': 'PCON11DBEL',
#  'Representative to Congress - District 11  Marcia L. Fudge (D)': 'PCON11DFUD',
#  'Representative to Congress - District 11  Michael Hood (D)': 'PCON11DHOO',
#  'Representative to Congress - District 11  Tariq K. Shabazz (D)': 'PCON11DSHA',
#  'Representative to Congress - District 12  Jenny Bell (D)': 'PCON12DBEL',
#  'Representative to Congress - District 12  Alaina Shearer (D)': 'PCON12DSHE',
#  'Representative to Congress - District 13  Tim Ryan (D)': 'PCON13DRYA',
#  "Representative to Congress - District 14  Hillary O'Connor Mueri (D)": 'PCON14DMUE',
#  'Representative to Congress - District 15  Daniel McArthur Kilgore (D)': 'PCON15DKIL',
#  'Representative to Congress - District 15  Joel Newby (D)': 'PCON15DNEW',
#  'Representative to Congress - District 16  Aaron Paul Godfrey (D)': 'PCON16DGOD',
#  'Representative to Congress - District 16  Ronald Karpus III (D)': 'PCON16DKAR',
#  "Justice of the Supreme Court Term Commencing 01/01/2021 John P. O'Donnell (D)": 'PSSCKDODO',
#  'Justice of the Supreme Court Term Commencing 01/02/2021 Jennifer Brunner (D)': 'PSSCFDBRU',
#  "State Senator - District 02  Joel O'Dorisio (D)": 'PSU02DODO',
#  'State Senator - District 02  Reem Subei (D)': 'PSU02DSUB',
#  'State Senator - District 04  Kathy Wyenandt (D)': 'PSU04DWYE',
#  'State Senator - District 06  Mark Fogel (D)': 'PSU06DFOG',
#  'State Senator - District 06  Albert Griggs Jr (D)': 'PSU06DGRI',
#  'State Senator - District 08  Daniel Brown (D)': 'PSU08DBRO',
#  'State Senator - District 10  Charles Ballard (D)': 'PSU10DBAL',
#  'State Senator - District 12  Ken Poling (D)': 'PSU12DPOL',
#  'State Senator - District 14  Ryan Ottney (D)': 'PSU14DOTT',
#  'State Senator - District 16  Mark L. Bailey (D)': 'PSU16DBAI',
#  'State Senator - District 16  Troy Doucet (D)': 'PSU16DDOU',
#  'State Senator - District 16  Crystal Lett (D)': 'PSU16DLET',
#  'State Senator - District 18  Betsy Rader (D)': 'PSU18DRAD',
#  'State Senator - District 20  Christian N. Johnson (D)': 'PSU20DJOH',
#  'State Senator - District 22  Steve Johnson (D)': 'PSU22DJOH',
#  'State Senator - District 24  Tom Jackson (D)': 'PSU24DJAC',
#  'State Senator - District 26  Craig Swartz (D)': 'PSU26DSWA',
#  'State Senator - District 28  Vernon Sykes (D)': 'PSU28DSYK',
#  'State Senator - District 30  Michael Fletcher (D)': 'PSU30DFLE',
#  "State Senator - District 32  Sean J. O'Brien (D)": 'PSU32DOBR',
#  'State Representative - District 01  Alison Theiss (D)': 'PSL01DTHE',
#  'State Representative - District 03  Laurel Johnson (D)': 'PSL03DJOH',
#  'State Representative - District 05  Daniel Winston (D)': 'PSL05DWIN',
#  'State Representative - District 06  Phil Robinson (D)': 'PSL06DROB',
#  'State Representative - District 07  Joan T. Sweeny (D)': 'PSL07DSWE',
#  'State Representative - District 08  Kent Smith (D)': 'PSL08DSMI',
#  'State Representative - District 09  Janine Boyd (D)': 'PSL09DBOY',
#  'State Representative - District 09  Vincent E. Stokes II (D)': 'PSL09DSTO',
#  'State Representative - District 10  J. Allen Burger (D)': 'PSL10DBUR',
#  'State Representative - District 10  Terrence Upchurch (D)': 'PSL10DUPC',
#  'State Representative - District 11  Stephanie Howse (D)': 'PSL11DHOW',
#  'State Representative - District 12  Juanita Brent (D)': 'PSL12DBRE',
#  'State Representative - District 12  Felicia Washington Ross (D)': 'PSL12DROS',
#  'State Representative - District 13  Michael J. Skindell (D)': 'PSL13DSKI',
#  'State Representative - District 14  Bride Rose Sweeney (D)': 'PSL14DSWE',
#  'State Representative - District 15  Jeffrey A. Crossman (D)': 'PSL15DCRO',
#  'State Representative - District 16  Joe Romano (D)': 'PSL16DROM',
#  'State Representative - District 16  Monique Smith (D)': 'PSL16DSMI',
#  'State Representative - District 17  Adam C. Miller (D)': 'PSL17DMIL',
#  'State Representative - District 18  Kristin Boggs (D)': 'PSL18DBOG',
#  'State Representative - District 19  Mary Lightbody (D)': 'PSL19DLIG',
#  'State Representative - District 20  Richard Brown (D)': 'PSL20DBRO',
#  'State Representative - District 21  Beth Liston (D)': 'PSL21DLIS',
#  'State Representative - District 22  Kashi Adhikari (D)': 'PSL22DADH',
#  'State Representative - District 22  David Leland (D)': 'PSL22DLEL',
#  'State Representative - District 23  Nancy Day-Achauer (D)': 'PSL23DDAY',
#  'State Representative - District 24  Allison Russo (D)': 'PSL24DRUS',
#  'State Representative - District 25  Mohamud Jama (D)': 'PSL25DJAM',
#  'State Representative - District 25  Dontavius Jarrells (D)': 'PSL25DJAR',
#  'State Representative - District 25  Gary Josephson (D)': 'PSL25DJOS',
#  'State Representative - District 25  Mayo Makinde (D)': 'PSL25DMAK',
#  'State Representative - District 25  Kofi Nsia-Pepra (D)': 'PSL25DNSI',
#  'State Representative - District 26  Erica C. Crawley (D)': 'PSL26DCRA',
#  'State Representative - District 27  Sara Bitter (D)': 'PSL27DBIT',
#  'State Representative - District 28  Jessica E. Miranda (D)': 'PSL28DMIR',
#  'State Representative - District 31  Brigid Kelly (D)': 'PSL31DKEL',
#  'State Representative - District 32  Catherine D. Ingram (D)': 'PSL32DING',
#  'State Representative - District 32  Dadrien Washington (D)': 'PSL32DWAS',
#  'State Representative - District 33  Sedrick Denson (D)': 'PSL33DDEN',
#  'State Representative - District 33  Terence Allen Gragston (D)': 'PSL33DGRA',
#  'State Representative - District 34  Emilia Sykes (D)': 'PSL34DSYK',
#  'State Representative - District 35  Tavia Galonski (D)': 'PSL35DGAL',
#  'State Representative - District 36  A. J. Harris (D)': 'PSL36DHAR',
#  'State Representative - District 36  Matt Shaughnessy (D)': 'PSL36DSHA',
#  'State Representative - District 37  Casey Weinstein (D)': 'PSL37DWEI',
#  'State Representative - District 38  Joe Campbell (D)': 'PSL38DCAM',
#  'State Representative - District 39  Willis E. Blackshear Jr (D)': 'PSL39DBLA',
#  'State Representative - District 39  Walter J. Hickman Jr (D)': 'PSL39DHIC',
#  "State Representative - District 39  Jo'el Jones (D)": 'PSL39DJON',
#  'State Representative - District 40  Leronda Jackson (D)': 'PSL40DJAC',
#  'State Representative - District 41  Cate Berger (D)': 'PSL41DBER',
#  'State Representative - District 43  Amy Cox (D)': 'PSL43DCOX',
#  'State Representative - District 45  Lisa A. Sobecki (D)': 'PSL45DSOB',
#  'State Representative - District 46  Michael P. Sheehy (D)': 'PSL46DSHE',
#  'State Representative - District 47  Nancy Larson (D)': 'PSL47DLAR',
#  'State Representative - District 49  Thomas E. West (D)': 'PSL49DWES',
#  'State Representative - District 50  Brian K Simeone (D)': 'PSL50DSIM',
#  'State Representative - District 52  Chuck Horn (D)': 'PSL52DHOR',
#  'State Representative - District 53  Michelle E. Novak (D)': 'PSL53DNOV',
#  'State Representative - District 54  Morgan Showen (D)': 'PSL54DSHO',
#  'State Representative - District 55  Zach Stepp (D)': 'PSL55DSTE',
#  'State Representative - District 56  Joe Miller (D)': 'PSL56DMIL',
#  'State Representative - District 57  Dara Adkison (D)': 'PSL57DADK',
#  'State Representative - District 58  Michele Lepore Hagan (D)': 'PSL58DHAG',
#  'State Representative - District 59  Chris Stanley (D)': 'PSL59DSTA',
#  'State Representative - District 60  Daniel P. Troy (D)': 'PSL60DTRO',
#  'State Representative - District 61  Adam Dudziak (D)': 'PSL61DDUD',
#  'State Representative - District 62  Erin Rosiello (D)': 'PSL62DROS',
#  'State Representative - District 63  Gil Blair (D)': 'PSL63DBLA',
#  'State Representative - District 63  Werner Lange (D)': 'PSL63DLAN',
#  'State Representative - District 63  Barry Profato (D)': 'PSL63DPRO',
#  "State Representative - District 64  Michael J. O'Brien (D)": 'PSL64DOBR',
#  'State Representative - District 65  Alan Darnowsky (D)': 'PSL65DDAR',
#  'State Representative - District 67  Rachael Morocco (D)': 'PSL67DMOR',
#  'State Representative - District 68  Steven F. Mount (D)': 'PSL68DMOU',
#  'State Representative - District 69  Donna Beheydt (D)': 'PSL69DBEH',
#  'State Representative - District 70  Kevin Barnet (D)': 'PSL70DBAR',
#  'State Representative - District 71  Mark Carr (D)': 'PSL71DCAR',
#  'State Representative - District 73  Kim McCarthy (D)': 'PSL73DMCC',
#  'State Representative - District 75  Randi Clites (D)': 'PSL75DCLI',
#  'State Representative - District 76  Garrett Westhoven (D)': 'PSL76DWES',
#  'State Representative - District 77  Melissa Wilde (D)': 'PSL77DWIL',
#  'State Representative - District 78  Charlotte Owens (D)': 'PSL78DOWE',
#  'State Representative - District 79  Cynthia Richards (D)': 'PSL79DRIC',
#  'State Representative - District 84  Joseph A. Monbeck (D)': 'PSL84DMON',
#  'State Representative - District 86  Tiffanie Roberts (D)': 'PSL86DROB',
#  'State Representative - District 87  Nicholas Barnes (D)': 'PSL87DBAR',
#  'State Representative - District 88  Chris Liebold (D)': 'PSL88DLIE',
#  'State Representative - District 89  Alexis Miller (D)': 'PSL89DMIL',
#  'State Representative - District 91  Scott M. Dailey (D)': 'PSL91DDAI',
#  'State Representative - District 92  Beth Workman (D)': 'PSL92DWOR',
#  "State Representative - District 94  Katie O'Neill (D)": 'PSL94DONE',
#  'State Representative - District 96  Charlie DiPalma (D)': 'PSL96DDIP',
#  'State Representative - District 96  Richard A. Olivito (D)': 'PSL96DOLI',
#  'State Representative - District 97  Alaina Swope (D)': 'PSL97DSWO',
#  'State Representative - District 98  Todd E Beegle (D)': 'PSL98DBEE',
#  'State Representative - District 99  Richard Dana (D)': 'PSL99DDAN',
#  'President (at-large)  Donald J. Trump (R)': 'PPRERTRU',
#  'Representative to Congress - District 01  Steve Chabot (R)': 'PCON01RCHA',
#  'Representative to Congress - District 02  H. Robert Harris (R)': 'PCON02RHAR',
#  'Representative to Congress - District 02  Brad Wenstrup (R)': 'PCON02RWEN',
#  'Representative to Congress - District 03  Cleophus Dulaney (R)': 'PCON03RDUL',
#  'Representative to Congress - District 03  Mark F. Richardson (R)': 'PCON03RRIC',
#  'Representative to Congress - District 04  Jim Jordan (R)': 'PCON04RJOR',
#  'Representative to Congress - District 05  Bob Latta (R)': 'PCON05RLAT',
#  'Representative to Congress - District 06  Bill Johnson (R)': 'PCON06RJOH',
#  'Representative to Congress - District 06  Kenneth Morgan (R)': 'PCON06RMOR',
#  'Representative to Congress - District 07  Bob Gibbs (R)': 'PCON07RGIB',
#  'Representative to Congress - District 08  Warren Davidson (R)': 'PCON08RDAV',
#  'Representative to Congress - District 08  Edward R. Meer (R)': 'PCON08RMEE',
#  'Representative to Congress - District 09  Charles W. Barrett (R)': 'PCON09RBAR',
#  'Representative to Congress - District 09  Tim Connors (R)': 'PCON09RCON',
#  'Representative to Congress - District 09  Timothy P. Corrigan (R)': 'PCON09RCOR',
#  'Representative to Congress - District 09  Rob Weber (R)': 'PCON09RWEB',
#  'Representative to Congress - District 10  John Anderson (R)': 'PCON10RAND',
#  'Representative to Congress - District 10  Kathi Flanders (R)': 'PCON10RFLA',
#  'Representative to Congress - District 10  Mike Turner (R)': 'PCON10RTUR',
#  'Representative to Congress - District 11  Laverne Gore (R)': 'PCON11RGOR',
#  'Representative to Congress - District 11  Jonah Schulz (R)': 'PCON11RSCH',
#  'Representative to Congress - District 11  Shalira Taylor (R)': 'PCON11RTAY',
#  'Representative to Congress - District 12  Troy Balderson (R)': 'PCON12RBAL',
#  'Representative to Congress - District 12  Tim Day (R)': 'PCON12RDAY',
#  'Representative to Congress - District 13  Christina M. Hagan (R)': 'PCON13RHAG',
#  'Representative to Congress - District 13  Duane Hennen (R)': 'PCON13RHEN',
#  'Representative to Congress - District 13  Louis G. Lyras (R)': 'PCON13RLYR',
#  'Representative to Congress - District 13  Richard A. Morckel (R)': 'PCON13RMOR',
#  'Representative to Congress - District 13  Jason Mormando (R)': 'PCON13RMOR',
#  'Representative to Congress - District 13  Robert J. Santos (R)': 'PCON13RSAN',
#  'Representative to Congress - District 13  Donald Truex (R)': 'PCON13RTRU',
#  'Representative to Congress - District 14  David P. Joyce (R)': 'PCON14RJOY',
#  'Representative to Congress - District 14  Mark Pitrone (R)': 'PCON14RPIT',
#  'Representative to Congress - District 15  Shelby Xavier Hunt (R)': 'PCON15RHUN',
#  'Representative to Congress - District 15  Steve Stivers (R)': 'PCON15RSTI',
#  'Representative to Congress - District 16  Anthony Gonzalez (R)': 'PCON16RGON',
#  'Justice of the Supreme Court Term Commencing 01/01/2021 Sharon L. Kennedy (R)': 'PSSCKRKEN',
#  'Justice of the Supreme Court Term Commencing 01/02/2021 Judi French (R)': 'PSSCFRFRE',
#  'State Senator - District 02  Theresa Gavarone (R)': 'PSU02RGAV',
#  'State Senator - District 04  Candice Keller (R)': 'PSU04RKEL',
#  'State Senator - District 04  George F. Lang (R)': 'PSU04RLAN',
#  'State Senator - District 04  Lee Wong (R)': 'PSU04RWON',
#  'State Senator - District 06  Niraj Antani (R)': 'PSU06RANT',
#  'State Senator - District 06  Gregory Alan Robinson (R)': 'PSU06RROB',
#  'State Senator - District 06  Rachel Selby (R)': 'PSU06RSEL',
#  'State Senator - District 08  Louis W. Blessing III (R)': 'PSU08RBLE',
#  'State Senator - District 10  Robert D. Hackett (R)': 'PSU10RHAC',
#  'State Senator - District 12  Matt Huffman (R)': 'PSU12RHUF',
#  'State Senator - District 14  Terry A. Johnson (R)': 'PSU14RJOH',
#  'State Senator - District 14  David Uible (R)': 'PSU14RUIB',
#  'State Senator - District 16  Stephanie L. Kunze (R)': 'PSU16RKUN',
#  'State Senator - District 18  Jerry Cirino (R)': 'PSU18RCIR',
#  'State Senator - District 20  Tim Schaffer (R)': 'PSU20RSCH',
#  'State Senator - District 22  Cory T. Branham (R)': 'PSU22RBRA',
#  'State Senator - District 22  Ron Falconi (R)': 'PSU22RFAL',
#  'State Senator - District 22  Timothy Hoven (R)': 'PSU22RHOV',
#  'State Senator - District 22  Michael Reynolds (R)': 'PSU22RREY',
#  'State Senator - District 22  Mark Romanchuk (R)': 'PSU22RROM',
#  'State Senator - District 24  Matt Dolan (R)': 'PSU24RDOL',
#  'State Senator - District 26  Melissa Ackison (R)': 'PSU26RACK',
#  'State Senator - District 26  Bill Reineke (R)': 'PSU26RREI',
#  'State Senator - District 28  Michael Downey (R)': 'PSU28RDOW',
#  'State Senator - District 30  Frank Hoagland (R)': 'PSU30RHOA',
#  "State Senator - District 32  Sandra O'Brien (R)": 'PSU32ROBR',
#  'State Senator - District 32  Kenneth J. Polke (R)': 'PSU32RPOL',
#  'State Representative - District 01  Jason Wetz (R)': 'PSL01RWET',
#  'State Representative - District 01  Scott Wiggam (R)': 'PSL01RWIG',
#  'State Representative - District 02  Marilyn John (R)': 'PSL02RJOH',
#  'State Representative - District 02  Nathan Martin (R)': 'PSL02RMAR',
#  'State Representative - District 03  Haraz N. Ghanbari (R)': 'PSL03RGHA',
#  'State Representative - District 04  Bob Cupp (R)': 'PSL04RCUP',
#  'State Representative - District 05  Tim Ginter (R)': 'PSL05RGIN',
#  'State Representative - District 06  Ed Hargate (R)': 'PSL06RHAR',
#  'State Representative - District 06  Shay Hawkins (R)': 'PSL06RHAW',
#  'State Representative - District 07  Thomas F. Patton (R)': 'PSL07RPAT',
#  'State Representative - District 09  Dustin D. Russell (R)': 'PSL09RRUS',
#  'State Representative - District 14  Lynn McMahan (R)': 'PSL14RMCM',
#  'State Representative - District 15  Kevin C. Kussmaul (R)': 'PSL15RKUS',
#  'State Representative - District 16  Dave Greenspan (R)': 'PSL16RGRE',
#  'State Representative - District 17  Tim D. Haske (R)': 'PSL17RHAS',
#  'State Representative - District 17  John PM Rutan (R)': 'PSL17RRUT',
#  'State Representative - District 18  Kayla Anne Packard (R)': 'PSL18RPAC',
#  'State Representative - District 19  Meredith Freedhoff (R)': 'PSL19RFRE',
#  'State Representative - District 20  Chris Baer (R)': 'PSL20RBAE',
#  'State Representative - District 21  Mehek Cooke (R)': 'PSL21RCOO',
#  'State Representative - District 22  Stephany Spencer (R)': 'PSL22RSPE',
#  'State Representative - District 23  Laura Lanese (R)': 'PSL23RLAN',
#  'State Representative - District 24  Pat Manley (R)': 'PSL24RMAN',
#  'State Representative - District 25  Jim Burgess (R)': 'PSL25RBUR',
#  'State Representative - District 27  Tom Brinkman (R)': 'PSL27RBRI',
#  'State Representative - District 28  Chris Monzel (R)': 'PSL28RMON',
#  'State Representative - District 29  Cindy Abrams (R)': 'PSL29RABR',
#  'State Representative - District 30  Bill Seitz (R)': 'PSL30RSEI',
#  'State Representative - District 33  Mary L. Hill (R)': 'PSL33RHIL',
#  'State Representative - District 34  Henry Todd (R)': 'PSL34RTOD',
#  'State Representative - District 35  Jodi Sarver (R)': 'PSL35RSAR',
#  'State Representative - District 36  Bob Young (R)': 'PSL36RYOU',
#  'State Representative - District 37  Beth Bigham (R)': 'PSL37RBIG',
#  'State Representative - District 38  Bill Roemer (R)': 'PSL38RROE',
#  'State Representative - District 39  John Ferrell Mullins III (R)': 'PSL39RMUL',
#  'State Representative - District 40  Phil Plummer (R)': 'PSL40RPLU',
#  'State Representative - District 41  Andrea White (R)': 'PSL41RWHI',
#  'State Representative - District 42  Jake Stubbs (R)': 'PSL42RSTU',
#  'State Representative - District 42  Tom Young (R)': 'PSL42RYOU',
#  'State Representative - District 43  Rodney Creech (R)': 'PSL43RCRE',
#  'State Representative - District 43  J. Todd Smith (R)': 'PSL43RSMI',
#  'State Representative - District 44  Robert McMahon (R)': 'PSL44RMCM',
#  'State Representative - District 45  Shane Logan (R)': 'PSL45RLOG',
#  'State Representative - District 46  Steven R. Salander (R)': 'PSL46RSAL',
#  'State Representative - District 47  Derek Merrin (R)': 'PSL47RMER',
#  'State Representative - District 48  Scott Oelslager (R)': 'PSL48ROEL',
#  'State Representative - District 49  James Haavisto (R)': 'PSL49RHAA',
#  'State Representative - District 50  Reggie Stoltzfus (R)': 'PSL50RSTO',
#  'State Representative - District 51  Sara P. Carruthers (R)': 'PSL51RCAR',
#  'State Representative - District 52  Jennifer L. Gross (R)': 'PSL52RGRO',
#  'State Representative - District 52  Mark S. Welch (R)': 'PSL52RWEL',
#  'State Representative - District 53  Brett Guido (R)': 'PSL53RGUI',
#  'State Representative - District 53  Thomas Hall (R)': 'PSL53RHAL',
#  'State Representative - District 53  Diane Mullins (R)': 'PSL53RMUL',
#  'State Representative - District 54  Paul Zeltwanger (R)': 'PSL54RZEL',
#  'State Representative - District 55  Gayle Manning (R)': 'PSL55RMAN',
#  'State Representative - District 56  Bradley A. Lacko (R)': 'PSL56RLAC',
#  'State Representative - District 57  Dick Stein (R)': 'PSL57RSTE',
#  'State Representative - District 58  David T. Simon (R)': 'PSL58RSIM',
#  'State Representative - District 59  Don Manning (R)': 'PSL59RMAN',
#  'State Representative - District 60  George M. Phillips (R)': 'PSL60RPHI',
#  'State Representative - District 61  Jamie Callender (R)': 'PSL61RCAL',
#  'State Representative - District 62  Scott Lipps (R)': 'PSL62RLIP',
#  'State Representative - District 63  Mike Loychik (R)': 'PSL63RLOY',
#  'State Representative - District 64  Martha Yoder (R)': 'PSL64RYOD',
#  'State Representative - District 65  Dillon Blevins (R)': 'PSL65RBLE',
#  'State Representative - District 65  Joe Dills (R)': 'PSL65RDIL',
#  'State Representative - District 65  Jean Schmidt (R)': 'PSL65RSCH',
#  'State Representative - District 66  Adam C. Bird (R)': 'PSL66RBIR',
#  'State Representative - District 66  Allen Freeman (R)': 'PSL66RFRE',
#  'State Representative - District 66  Nick Owens (R)': 'PSL66ROWE',
#  'State Representative - District 67  Kris Jordan (R)': 'PSL67RJOR',
#  'State Representative - District 68  Rick Carfagna (R)': 'PSL68RCAR',
#  'State Representative - District 69  Sharon A. Ray (R)': 'PSL69RRAY',
#  'State Representative - District 70  Darrell D. Kick (R)': 'PSL70RKIC',
#  'State Representative - District 70  Terry Robertson (R)': 'PSL70RROB',
#  'State Representative - District 71  Thaddeus James Claggett (R)': 'PSL71RCLA',
#  'State Representative - District 71  Mark D. Fraizer (R)': 'PSL71RFRA',
#  'State Representative - District 72  Larry Householder (R)': 'PSL72RHOU',
#  'State Representative - District 73  John Broughton (R)': 'PSL73RBRO',
#  'State Representative - District 73  Brian Lampton (R)': 'PSL73RLAM',
#  'State Representative - District 74  Bill Dean (R)': 'PSL74RDEA',
#  'State Representative - District 75  Gail Pavliga (R)': 'PSL75RPAV',
#  'State Representative - District 76  Diane V. Grendell (R)': 'PSL76RGRE',
#  'State Representative - District 76  Frank Hall (R)': 'PSL76RHAL',
#  'State Representative - District 77  Jeff LaRe (R)': 'PSL77RLAR',
#  'State Representative - District 78  Aaron Adams (R)': 'PSL78RADA',
#  'State Representative - District 78  Bobby Mitchell (R)': 'PSL78RMIT',
#  'State Representative - District 78  Brian Stewart (R)': 'PSL78RSTE',
#  'State Representative - District 79  Kyle Koehler (R)': 'PSL79RKOE',
#  'State Representative - District 80  Jena Powell (R)': 'PSL80RPOW',
#  'State Representative - District 81  James M. Hoops (R)': 'PSL81RHOO',
#  'State Representative - District 82  Craig S. Riedel (R)': 'PSL82RRIE',
#  'State Representative - District 83  Jon Cross (R)': 'PSL83RCRO',
#  'State Representative - District 84  Susan Manchester (R)': 'PSL84RMAN',
#  'State Representative - District 85  Nino Vitale (R)': 'PSL85RVIT',
#  'State Representative - District 86  Tracy Richardson (R)': 'PSL86RRIC',
#  'State Representative - District 87  Riordan T. McClain (R)': 'PSL87RMCC',
#  'State Representative - District 88  Gary N. Click (R)': 'PSL88RCLI',
#  'State Representative - District 88  Ed Ollom (R)': 'PSL88ROLL',
#  'State Representative - District 88  Shayne Thomas (R)': 'PSL88RTHO',
#  'State Representative - District 89  D.J. Swearingen (R)': 'PSL89RSWE',
#  'State Representative - District 90  Brian Baldridge (R)': 'PSL90RBAL',
#  'State Representative - District 91  Shane Wilkin (R)': 'PSL91RWIL',
#  'State Representative - District 92  Mark Johnson (R)': 'PSL92RJOH',
#  'State Representative - District 93  Jeff Halley (R)': 'PSL93RHAL',
#  'State Representative - District 93  Jason C. Stephens (R)': 'PSL93RSTE',
#  'State Representative - District 94  Jay Edwards (R)': 'PSL94REDW',
#  'State Representative - District 95  Don Jones (R)': 'PSL95RJON',
#  'State Representative - District 96  Ron Ferguson (R)': 'PSL96RFER',
#  'State Representative - District 97  Adam Holmes (R)': 'PSL97RHOL',
#  'State Representative - District 98  Brett Hudson Hillyer (R)': 'PSL98RHIL',
#  'State Representative - District 99  Sarah E. Fowler (R)': 'PSL99RFOW',
#  'Representative to Congress - District 01  Kevin David Kahn (L)': 'PCON01LKAH',
#  'Representative to Congress - District 04  Steve Perkins (L)': 'PCON04LPER',
#  'Representative to Congress - District 07  Brandon Lape (L)': 'PCON07LLAP',
#  'Representative to Congress - District 13  Michael Fricke (L)': 'PCON13LFRI',
#  'State Representative - District 96  Oscar Herrera (L)': 'PSL96LHER'}

# %%
elections_2020.rename(columns=contest_name_change_dict,inplace=True)

# %% [markdown]
# ### Filter Down to Relevant Columns

# %%
keeper_columns = ['County Name','Precinct Name','Precinct Code','Region Name','Media Market','Registered Voters','COUNTYFP']
state_house_contests = [i for i in list(elections_2020.columns) if "PSL" in i]

# %%
elections_2020 = elections_2020[keeper_columns+state_house_contests]

# %% [markdown]
# ### Compare Precinct Totals

# %%
elections_2020["UNIQUE_ID"] = elections_2020["COUNTYFP"]+"-"+elections_2020["Precinct Code"]
vest_oh_20["UNIQUE_ID"] = vest_oh_20["COUNTYFP20"]+"-"+vest_oh_20["PRECINCT20"]

# %%
#Confirm unique IDs are unique
print(elections_2020["UNIQUE_ID"].value_counts(dropna=False))
print(vest_oh_20["UNIQUE_ID"].value_counts(dropna=False))
# Out:
# 161-AAG    1
# 113-AHJ    1
# 095-AJQ    1
# 085-AAP    1
# 135-AAF    1
#           ..
# 145-ACQ    1
# 103-ABS    1
# 047-AAA    1
# 049-BKS    1
# 061-BJL    1
# Name: UNIQUE_ID, Length: 8933, dtype: int64
# 107-ABG    1
# 061-BKW    1
# 117-AAA    1
# 143-AAQ    1
# 049-AHM    1
#           ..
# 023-ABX    1
# 023-ABI    1
# 017-AAX    1
# 153-BAC    1
# 061-BJL    1
# Name: UNIQUE_ID, Length: 8941, dtype: int64

# %%
global attempt_one
attempt_one = pd.merge(vest_oh_20,elections_2020,how="outer",on="UNIQUE_ID",indicator=True)
print(attempt_one["_merge"].value_counts())

vest_only = attempt_one[attempt_one["_merge"]=="left_only"]
elections_only = attempt_one[attempt_one["_merge"]=="right_only"]
# Out:
# both          8933
# left_only        8
# right_only       0
# Name: _merge, dtype: int64

# %%
#Confirm these are all zero-vote races
races =["UNIQUE_ID"]

for val in ['G20PRERTRU', 'G20PREDBID', 'G20PRELJOR','G20PREGHAW']:
    races.append(val)

print((vest_only[races]))
# Out:
#      UNIQUE_ID  G20PRERTRU  G20PREDBID  G20PRELJOR  G20PREGHAW
# 814    093-ZZZ           0           0           0           0
# 982    123-ZZZ           0           0           0           0
# 2924   095-ZZZ           0           0           0           0
# 3674   043-ZZZ           0           0           0           0
# 4389   085-ZZZ           0           0           0           0
# 4565   035-ZZZ           0           0           0           0
# 5357   133-ZZZ           0           0           0           0
# 7951   007-ZZZ           0           0           0           0

# %% [markdown]
# ## Perform Splits

# %%
def return_sll_splits(split_dict):
    for val in split_dict.keys():
        if 'SL' in val:
            return split_dict['SL']

# %%
sll_splits_dict = {i:return_sll_splits(split_precincts_list[i]) for i in split_precincts_list.keys() if return_sll_splits(split_precincts_list[i]) != None }

# %% [markdown]
# #### Load in the shapefile

# %%
oh_sll_districts = gp.read_file("./raw-from-source/District_Shapefiles/oh_pl2020_sldl/oh_pl2020_sldl.shp")

# %%
oh_sll_districts.drop(['STATEFP20', 'GEOID20'], axis = 1, inplace = True)

# %%
oh_sll_districts = oh_sll_districts.to_crs(vest_oh_20.crs)
oh_sll_districts["SLDLST"] = oh_sll_districts["SLDLST20"].str[1:3]

# %%
list(attempt_one.columns)
# Out:
# ['STATEFP20',
#  'COUNTYFP20',
#  'VTDST20',
#  'PRECINCT20',
#  'GEOID20',
#  'NAME20',
#  'G20PRERTRU',
#  'G20PREDBID',
#  'G20PRELJOR',
#  'G20PREGHAW',
#  'geometry',
#  'UNIQUE_ID',
#  'County Name',
#  'Precinct Name',
#  'Precinct Code',
#  'Region Name',
#  'Media Market',
#  'Registered Voters',
#  'COUNTYFP',
#  'PSL01DTHE',
#  'PSL03DJOH',
#  'PSL05DWIN',
#  'PSL06DROB',
#  'PSL07DSWE',
#  'PSL08DSMI',
#  'PSL09DBOY',
#  'PSL09DSTO',
#  'PSL10DBUR',
#  'PSL10DUPC',
#  'PSL11DHOW',
#  'PSL12DBRE',
#  'PSL12DROS',
#  'PSL13DSKI',
#  'PSL14DSWE',
#  'PSL15DCRO',
#  'PSL16DROM',
#  'PSL16DSMI',
#  'PSL17DMIL',
#  'PSL18DBOG',
#  'PSL19DLIG',
#  'PSL20DBRO',
#  'PSL21DLIS',
#  'PSL22DADH',
#  'PSL22DLEL',
#  'PSL23DDAY',
#  'PSL24DRUS',
#  'PSL25DJAM',
#  'PSL25DJAR',
#  'PSL25DJOS',
#  'PSL25DMAK',
#  'PSL25DNSI',
#  'PSL26DCRA',
#  'PSL27DBIT',
#  'PSL28DMIR',
#  'PSL31DKEL',
#  'PSL32DING',
#  'PSL32DWAS',
#  'PSL33DDEN',
#  'PSL33DGRA',
#  'PSL34DSYK',
#  'PSL35DGAL',
#  'PSL36DHAR',
#  'PSL36DSHA',
#  'PSL37DWEI',
#  'PSL38DCAM',
#  'PSL39DBLA',
#  'PSL39DHIC',
#  'PSL39DJON',
#  'PSL40DJAC',
#  'PSL41DBER',
#  'PSL43DCOX',
#  'PSL45DSOB',
#  'PSL46DSHE',
#  'PSL47DLAR',
#  'PSL49DWES',
#  'PSL50DSIM',
#  'PSL52DHOR',
#  'PSL53DNOV',
#  'PSL54DSHO',
#  'PSL55DSTE',
#  'PSL56DMIL',
#  'PSL57DADK',
#  'PSL58DHAG',
#  'PSL59DSTA',
#  'PSL60DTRO',
#  'PSL61DDUD',
#  'PSL62DROS',
#  'PSL63DBLA',
#  'PSL63DLAN',
#  'PSL63DPRO',
#  'PSL64DOBR',
#  'PSL65DDAR',
#  'PSL67DMOR',
#  'PSL68DMOU',
#  'PSL69DBEH',
#  'PSL70DBAR',
#  'PSL71DCAR',
#  'PSL73DMCC',
#  'PSL75DCLI',
#  'PSL76DWES',
#  'PSL77DWIL',
#  'PSL78DOWE',
#  'PSL79DRIC',
#  'PSL84DMON',
#  'PSL86DROB',
#  'PSL87DBAR',
#  'PSL88DLIE',
#  'PSL89DMIL',
#  'PSL91DDAI',
#  'PSL92DWOR',
#  'PSL94DONE',
#  'PSL96DDIP',
#  'PSL96DOLI',
#  'PSL97DSWO',
#  'PSL98DBEE',
#  'PSL99DDAN',
#  'PSL01RWET',
#  'PSL01RWIG',
#  'PSL02RJOH',
#  'PSL02RMAR',
#  'PSL03RGHA',
#  'PSL04RCUP',
#  'PSL05RGIN',
#  'PSL06RHAR',
#  'PSL06RHAW',
#  'PSL07RPAT',
#  'PSL09RRUS',
#  'PSL14RMCM',
#  'PSL15RKUS',
#  'PSL16RGRE',
#  'PSL17RHAS',
#  'PSL17RRUT',
#  'PSL18RPAC',
#  'PSL19RFRE',
#  'PSL20RBAE',
#  'PSL21RCOO',
#  'PSL22RSPE',
#  'PSL23RLAN',
#  'PSL24RMAN',
#  'PSL25RBUR',
#  'PSL27RBRI',
#  'PSL28RMON',
#  'PSL29RABR',
#  'PSL30RSEI',
#  'PSL33RHIL',
#  'PSL34RTOD',
#  'PSL35RSAR',
#  'PSL36RYOU',
#  'PSL37RBIG',
#  'PSL38RROE',
#  'PSL39RMUL',
#  'PSL40RPLU',
#  'PSL41RWHI',
#  'PSL42RSTU',
#  'PSL42RYOU',
#  'PSL43RCRE',
#  'PSL43RSMI',
#  'PSL44RMCM',
#  'PSL45RLOG',
#  'PSL46RSAL',
#  'PSL47RMER',
#  'PSL48ROEL',
#  'PSL49RHAA',
#  'PSL50RSTO',
#  'PSL51RCAR',
#  'PSL52RGRO',
#  'PSL52RWEL',
#  'PSL53RGUI',
#  'PSL53RHAL',
#  'PSL53RMUL',
#  'PSL54RZEL',
#  'PSL55RMAN',
#  'PSL56RLAC',
#  'PSL57RSTE',
#  'PSL58RSIM',
#  'PSL59RMAN',
#  'PSL60RPHI',
#  'PSL61RCAL',
#  'PSL62RLIP',
#  'PSL63RLOY',
#  'PSL64RYOD',
#  'PSL65RBLE',
#  'PSL65RDIL',
#  'PSL65RSCH',
#  'PSL66RBIR',
#  'PSL66RFRE',
#  'PSL66ROWE',
#  'PSL67RJOR',
#  'PSL68RCAR',
#  'PSL69RRAY',
#  'PSL70RKIC',
#  'PSL70RROB',
#  'PSL71RCLA',
#  'PSL71RFRA',
#  'PSL72RHOU',
#  'PSL73RBRO',
#  'PSL73RLAM',
#  'PSL74RDEA',
#  'PSL75RPAV',
#  'PSL76RGRE',
#  'PSL76RHAL',
#  'PSL77RLAR',
#  'PSL78RADA',
#  'PSL78RMIT',
#  'PSL78RSTE',
#  'PSL79RKOE',
#  'PSL80RPOW',
#  'PSL81RHOO',
#  'PSL82RRIE',
#  'PSL83RCRO',
#  'PSL84RMAN',
#  'PSL85RVIT',
#  'PSL86RRIC',
#  'PSL87RMCC',
#  'PSL88RCLI',
#  'PSL88ROLL',
#  'PSL88RTHO',
#  'PSL89RSWE',
#  'PSL90RBAL',
#  'PSL91RWIL',
#  'PSL92RJOH',
#  'PSL93RHAL',
#  'PSL93RSTE',
#  'PSL94REDW',
#  'PSL95RJON',
#  'PSL96RFER',
#  'PSL97RHOL',
#  'PSL98RHIL',
#  'PSL99RFOW',
#  'PSL96LHER',
#  '_merge']

# %%
final_races = ['PSL01DTHE',
 'PSL03DJOH',
 'PSL05DWIN',
 'PSL06DROB',
 'PSL07DSWE',
 'PSL08DSMI',
 'PSL09DBOY',
 'PSL09DSTO',
 'PSL10DBUR',
 'PSL10DUPC',
 'PSL11DHOW',
 'PSL12DBRE',
 'PSL12DROS',
 'PSL13DSKI',
 'PSL14DSWE',
 'PSL15DCRO',
 'PSL16DROM',
 'PSL16DSMI',
 'PSL17DMIL',
 'PSL18DBOG',
 'PSL19DLIG',
 'PSL20DBRO',
 'PSL21DLIS',
 'PSL22DADH',
 'PSL22DLEL',
 'PSL23DDAY',
 'PSL24DRUS',
 'PSL25DJAM',
 'PSL25DJAR',
 'PSL25DJOS',
 'PSL25DMAK',
 'PSL25DNSI',
 'PSL26DCRA',
 'PSL27DBIT',
 'PSL28DMIR',
 'PSL31DKEL',
 'PSL32DING',
 'PSL32DWAS',
 'PSL33DDEN',
 'PSL33DGRA',
 'PSL34DSYK',
 'PSL35DGAL',
 'PSL36DHAR',
 'PSL36DSHA',
 'PSL37DWEI',
 'PSL38DCAM',
 'PSL39DBLA',
 'PSL39DHIC',
 'PSL39DJON',
 'PSL40DJAC',
 'PSL41DBER',
 'PSL43DCOX',
 'PSL45DSOB',
 'PSL46DSHE',
 'PSL47DLAR',
 'PSL49DWES',
 'PSL50DSIM',
 'PSL52DHOR',
 'PSL53DNOV',
 'PSL54DSHO',
 'PSL55DSTE',
 'PSL56DMIL',
 'PSL57DADK',
 'PSL58DHAG',
 'PSL59DSTA',
 'PSL60DTRO',
 'PSL61DDUD',
 'PSL62DROS',
 'PSL63DBLA',
 'PSL63DLAN',
 'PSL63DPRO',
 'PSL64DOBR',
 'PSL65DDAR',
 'PSL67DMOR',
 'PSL68DMOU',
 'PSL69DBEH',
 'PSL70DBAR',
 'PSL71DCAR',
 'PSL73DMCC',
 'PSL75DCLI',
 'PSL76DWES',
 'PSL77DWIL',
 'PSL78DOWE',
 'PSL79DRIC',
 'PSL84DMON',
 'PSL86DROB',
 'PSL87DBAR',
 'PSL88DLIE',
 'PSL89DMIL',
 'PSL91DDAI',
 'PSL92DWOR',
 'PSL94DONE',
 'PSL96DDIP',
 'PSL96DOLI',
 'PSL97DSWO',
 'PSL98DBEE',
 'PSL99DDAN',
 'PSL01RWET',
 'PSL01RWIG',
 'PSL02RJOH',
 'PSL02RMAR',
 'PSL03RGHA',
 'PSL04RCUP',
 'PSL05RGIN',
 'PSL06RHAR',
 'PSL06RHAW',
 'PSL07RPAT',
 'PSL09RRUS',
 'PSL14RMCM',
 'PSL15RKUS',
 'PSL16RGRE',
 'PSL17RHAS',
 'PSL17RRUT',
 'PSL18RPAC',
 'PSL19RFRE',
 'PSL20RBAE',
 'PSL21RCOO',
 'PSL22RSPE',
 'PSL23RLAN',
 'PSL24RMAN',
 'PSL25RBUR',
 'PSL27RBRI',
 'PSL28RMON',
 'PSL29RABR',
 'PSL30RSEI',
 'PSL33RHIL',
 'PSL34RTOD',
 'PSL35RSAR',
 'PSL36RYOU',
 'PSL37RBIG',
 'PSL38RROE',
 'PSL39RMUL',
 'PSL40RPLU',
 'PSL41RWHI',
 'PSL42RSTU',
 'PSL42RYOU',
 'PSL43RCRE',
 'PSL43RSMI',
 'PSL44RMCM',
 'PSL45RLOG',
 'PSL46RSAL',
 'PSL47RMER',
 'PSL48ROEL',
 'PSL49RHAA',
 'PSL50RSTO',
 'PSL51RCAR',
 'PSL52RGRO',
 'PSL52RWEL',
 'PSL53RGUI',
 'PSL53RHAL',
 'PSL53RMUL',
 'PSL54RZEL',
 'PSL55RMAN',
 'PSL56RLAC',
 'PSL57RSTE',
 'PSL58RSIM',
 'PSL59RMAN',
 'PSL60RPHI',
 'PSL61RCAL',
 'PSL62RLIP',
 'PSL63RLOY',
 'PSL64RYOD',
 'PSL65RBLE',
 'PSL65RDIL',
 'PSL65RSCH',
 'PSL66RBIR',
 'PSL66RFRE',
 'PSL66ROWE',
 'PSL67RJOR',
 'PSL68RCAR',
 'PSL69RRAY',
 'PSL70RKIC',
 'PSL70RROB',
 'PSL71RCLA',
 'PSL71RFRA',
 'PSL72RHOU',
 'PSL73RBRO',
 'PSL73RLAM',
 'PSL74RDEA',
 'PSL75RPAV',
 'PSL76RGRE',
 'PSL76RHAL',
 'PSL77RLAR',
 'PSL78RADA',
 'PSL78RMIT',
 'PSL78RSTE',
 'PSL79RKOE',
 'PSL80RPOW',
 'PSL81RHOO',
 'PSL82RRIE',
 'PSL83RCRO',
 'PSL84RMAN',
 'PSL85RVIT',
 'PSL86RRIC',
 'PSL87RMCC',
 'PSL88RCLI',
 'PSL88ROLL',
 'PSL88RTHO',
 'PSL89RSWE',
 'PSL90RBAL',
 'PSL91RWIL',
 'PSL92RJOH',
 'PSL93RHAL',
 'PSL93RSTE',
 'PSL94REDW',
 'PSL95RJON',
 'PSL96RFER',
 'PSL97RHOL',
 'PSL98RHIL',
 'PSL99RFOW',
 'PSL96LHER']

# %%
for val in final_races:
    attempt_one[val] = attempt_one[val].fillna(0)
    attempt_one[val] = attempt_one[val].astype(int)
    print(val, sum(attempt_one[val]))
# Out:
# PSL01DTHE 4253
# PSL03DJOH 7243
# PSL05DWIN 3911
# PSL06DROB 10753
# PSL07DSWE 8082
# PSL08DSMI 11185
# PSL09DBOY 16008
# PSL09DSTO 2580
# PSL10DBUR 1355
# PSL10DUPC 6151
# PSL11DHOW 5760
# PSL12DBRE 10015
# PSL12DROS 2503
# PSL13DSKI 7628
# PSL14DSWE 7211
# PSL15DCRO 6014
# PSL16DROM 3839
# PSL16DSMI 9025
# PSL17DMIL 4559
# PSL18DBOG 11437
# PSL19DLIG 10916
# PSL20DBRO 7527
# PSL21DLIS 10834
# PSL22DADH 2680
# PSL22DLEL 10183
# PSL23DDAY 6172
# PSL24DRUS 11826
# PSL25DJAM 3203
# PSL25DJAR 6176
# PSL25DJOS 912
# PSL25DMAK 2354
# PSL25DNSI 1109
# PSL26DCRA 10656
# PSL27DBIT 8775
# PSL28DMIR 10026
# PSL31DKEL 10469
# PSL32DING 10200
# PSL32DWAS 1337
# PSL33DDEN 11004
# PSL33DGRA 3365
# PSL34DSYK 10789
# PSL35DGAL 5478
# PSL36DHAR 3294
# PSL36DSHA 6259
# PSL37DWEI 9612
# PSL38DCAM 7068
# PSL39DBLA 5478
# PSL39DHIC 826
# PSL39DJON 1646
# PSL40DJAC 5306
# PSL41DBER 7318
# PSL43DCOX 6664
# PSL45DSOB 5408
# PSL46DSHE 6533
# PSL47DLAR 6308
# PSL49DWES 5912
# PSL50DSIM 5460
# PSL52DHOR 5121
# PSL53DNOV 3696
# PSL54DSHO 6388
# PSL55DSTE 8862
# PSL56DMIL 10220
# PSL57DADK 6289
# PSL58DHAG 9840
# PSL59DSTA 8999
# PSL60DTRO 7679
# PSL61DDUD 7230
# PSL62DROS 4634
# PSL63DBLA 7936
# PSL63DLAN 1573
# PSL63DPRO 2879
# PSL64DOBR 8611
# PSL65DDAR 5396
# PSL67DMOR 9078
# PSL68DMOU 6385
# PSL69DBEH 7001
# PSL70DBAR 4727
# PSL71DCAR 6356
# PSL73DMCC 7202
# PSL75DCLI 8350
# PSL76DWES 6865
# PSL77DWIL 5271
# PSL78DOWE 4613
# PSL79DRIC 5723
# PSL84DMON 3305
# PSL86DROB 5021
# PSL87DBAR 3867
# PSL88DLIE 5473
# PSL89DMIL 7769
# PSL91DDAI 3225
# PSL92DWOR 4669
# PSL94DONE 5356
# PSL96DDIP 4359
# PSL96DOLI 5370
# PSL97DSWO 4139
# PSL98DBEE 4870
# PSL99DDAN 5836
# PSL01RWET 990
# PSL01RWIG 6924
# PSL02RJOH 7858
# PSL02RMAR 3474
# PSL03RGHA 5782
# PSL04RCUP 9420
# PSL05RGIN 6573
# PSL06RHAR 3095
# PSL06RHAW 3611
# PSL07RPAT 6561
# PSL09RRUS 1087
# PSL14RMCM 2770
# PSL15RKUS 2986
# PSL16RGRE 5353
# PSL17RHAS 1258
# PSL17RRUT 831
# PSL18RPAC 1117
# PSL19RFRE 4591
# PSL20RBAE 3348
# PSL21RCOO 4099
# PSL22RSPE 2520
# PSL23RLAN 4090
# PSL24RMAN 4386
# PSL25RBUR 1098
# PSL27RBRI 7574
# PSL28RMON 6589
# PSL29RABR 6494
# PSL30RSEI 7772
# PSL33RHIL 2261
# PSL34RTOD 1584
# PSL35RSAR 2282
# PSL36RYOU 4822
# PSL37RBIG 4200
# PSL38RROE 5333
# PSL39RMUL 889
# PSL40RPLU 6156
# PSL41RWHI 5947
# PSL42RSTU 2341
# PSL42RYOU 6644
# PSL43RCRE 5359
# PSL43RSMI 2817
# PSL44RMCM 1085
# PSL45RLOG 2183
# PSL46RSAL 2798
# PSL47RMER 5290
# PSL48ROEL 8453
# PSL49RHAA 3547
# PSL50RSTO 8240
# PSL51RCAR 5830
# PSL52RGRO 5382
# PSL52RWEL 4997
# PSL53RGUI 1360
# PSL53RHAL 3507
# PSL53RMUL 3001
# PSL54RZEL 9935
# PSL55RMAN 5737
# PSL56RLAC 3774
# PSL57RSTE 7554
# PSL58RSIM 2589
# PSL59RMAN 5917
# PSL60RPHI 6224
# PSL61RCAL 8887
# PSL62RLIP 9899
# PSL63RLOY 5545
# PSL64RYOD 4924
# PSL65RBLE 2113
# PSL65RDIL 5879
# PSL65RSCH 6197
# PSL66RBIR 4787
# PSL66RFRE 4199
# PSL66ROWE 4314
# PSL67RJOR 10976
# PSL68RCAR 12067
# PSL69RRAY 7679
# PSL70RKIC 6485
# PSL70RROB 3282
# PSL71RCLA 5374
# PSL71RFRA 5681
# PSL72RHOU 11142
# PSL73RBRO 4416
# PSL73RLAM 9579
# PSL74RDEA 10183
# PSL75RPAV 4602
# PSL76RGRE 7914
# PSL76RHAL 5180
# PSL77RLAR 7275
# PSL78RADA 924
# PSL78RMIT 2939
# PSL78RSTE 7820
# PSL79RKOE 6607
# PSL80RPOW 12471
# PSL81RHOO 11152
# PSL82RRIE 10984
# PSL83RCRO 12850
# PSL84RMAN 13284
# PSL85RVIT 11815
# PSL86RRIC 9762
# PSL87RMCC 12685
# PSL88RCLI 5555
# PSL88ROLL 3124
# PSL88RTHO 4789
# PSL89RSWE 5437
# PSL90RBAL 10493
# PSL91RWIL 7271
# PSL92RJOH 5411
# PSL93RHAL 5682
# PSL93RSTE 10177
# PSL94REDW 7895
# PSL95RJON 10919
# PSL96RFER 6734
# PSL97RHOL 7444
# PSL98RHIL 7582
# PSL99RFOW 7413
# PSL96LHER 18

# %%
global global_precinct_differences_dict
global_precinct_differences_dict = {}

# %%
def cd_splits(cd_list,level,old_name):
    global attempt_one
    full_shape = attempt_one.loc[attempt_one["UNIQUE_ID"]==old_name]
    #print(old_name,"->"," & ".join(new_id_list))
    for index in range(0,len(cd_list)):
        cd = oh_sll_districts.loc[oh_sll_districts["SLDLST"]==cd_list[index]]
        new_prec = gp.overlay(full_shape, cd, how='intersection',keep_geom_type=True)
        if(new_prec.empty):
            print("***Issue merging SLDL: ",cd_list[index],"and prec:",old_name,"***")
            for column in new_prec:
                if column in final_races and cd_list[index] in column:
                    print(column)
                    print(full_shape[column])
                    if column in global_precinct_differences_dict.keys():
                        global_precinct_differences_dict[column] += full_shape[column].values[0]
                    else:
                        global_precinct_differences_dict[column] = full_shape[column].values[0]
        new_prec = new_prec[list(attempt_one.columns)]
        for column in new_prec:
            if column in final_races and cd_list[index] not in column:
                new_prec.loc[0:,column] = 0 
        new_prec["UNIQUE_ID"]=old_name+"-("+level+"-"+cd_list[index]+")"
        attempt_one=attempt_one.append(new_prec)
        attempt_one.reset_index(drop=True,inplace=True)        
    #Remove the precinct that was split
    attempt_one=attempt_one[attempt_one["UNIQUE_ID"]!=old_name]
    attempt_one.reset_index(drop=True,inplace=True)

# %%
#Re-introduce the column from above

# Iterate over dataframe, get the results where splits will need to happen

for val in attempt_one["UNIQUE_ID"]:
    cd_list = []
    if val in sll_splits_dict.keys():
        #How we will actually call it
        cd_splits(sll_splits_dict[val],"SLL",val)
# Out:
# ***Issue merging SLDL:  85 and prec: 091-AAS ***
# PSL85RVIT
# 2591    1
# Name: PSL85RVIT, dtype: int64
# ***Issue merging SLDL:  94 and prec: 167-ACD ***
# PSL94DONE
# 5770    5
# Name: PSL94DONE, dtype: int64
# PSL94REDW
# 5770    0
# Name: PSL94REDW, dtype: int64
# ***Issue merging SLDL:  22 and prec: 049-AYU ***
# PSL22DADH
# 6646    0
# Name: PSL22DADH, dtype: int64
# PSL22DLEL
# 6646    1
# Name: PSL22DLEL, dtype: int64
# PSL22RSPE
# 6646    0
# Name: PSL22RSPE, dtype: int64
# ***Issue merging SLDL:  26 and prec: 049-AXI ***
# PSL26DCRA
# 6792    7
# Name: PSL26DCRA, dtype: int64
# ***Issue merging SLDL:  24 and prec: 049-ADF ***
# PSL24DRUS
# 6903    12
# Name: PSL24DRUS, dtype: int64
# PSL24RMAN
# 6903    1
# Name: PSL24RMAN, dtype: int64
# ***Issue merging SLDL:  25 and prec: 049-AIJ ***
# PSL25DJAM
# 6988    0
# Name: PSL25DJAM, dtype: int64
# PSL25DJAR
# 6988    4
# Name: PSL25DJAR, dtype: int64
# PSL25DJOS
# 6988    1
# Name: PSL25DJOS, dtype: int64
# PSL25DMAK
# 6988    0
# Name: PSL25DMAK, dtype: int64
# PSL25DNSI
# 6988    0
# Name: PSL25DNSI, dtype: int64
# PSL25RBUR
# 6988    0
# Name: PSL25RBUR, dtype: int64
# ***Issue merging SLDL:  25 and prec: 049-AIL ***
# PSL25DJAM
# 7003    1
# Name: PSL25DJAM, dtype: int64
# PSL25DJAR
# 7003    4
# Name: PSL25DJAR, dtype: int64
# PSL25DJOS
# 7003    0
# Name: PSL25DJOS, dtype: int64
# PSL25DMAK
# 7003    1
# Name: PSL25DMAK, dtype: int64
# PSL25DNSI
# 7003    2
# Name: PSL25DNSI, dtype: int64
# PSL25RBUR
# 7003    0
# Name: PSL25RBUR, dtype: int64
# ***Issue merging SLDL:  22 and prec: 049-AVN ***
# PSL22DADH
# 7142    0
# Name: PSL22DADH, dtype: int64
# PSL22DLEL
# 7142    1
# Name: PSL22DLEL, dtype: int64
# PSL22RSPE
# 7142    0
# Name: PSL22RSPE, dtype: int64
# ***Issue merging SLDL:  24 and prec: 049-AGY ***
# PSL24DRUS
# 7284    4
# Name: PSL24DRUS, dtype: int64
# PSL24RMAN
# 7284    0
# Name: PSL24RMAN, dtype: int64
# ***Issue merging SLDL:  17 and prec: 049-BBO ***
# PSL17DMIL
# 7310    1
# Name: PSL17DMIL, dtype: int64
# PSL17RHAS
# 7310    0
# Name: PSL17RHAS, dtype: int64
# PSL17RRUT
# 7310    0
# Name: PSL17RRUT, dtype: int64
# ***Issue merging SLDL:  49 and prec: 151-ANX ***
# PSL49DWES
# 7995    2
# Name: PSL49DWES, dtype: int64
# PSL49RHAA
# 7995    1
# Name: PSL49RHAA, dtype: int64
# ***Issue merging SLDL:  53 and prec: 017-ACG ***
# PSL53DNOV
# 8351    1
# Name: PSL53DNOV, dtype: int64
# PSL53RGUI
# 8351    0
# Name: PSL53RGUI, dtype: int64
# PSL53RHAL
# 8351    1
# Name: PSL53RHAL, dtype: int64
# PSL53RMUL
# 8351    2
# Name: PSL53RMUL, dtype: int64
# ***Issue merging SLDL:  23 and prec: 049-AYR ***
# PSL23DDAY
# 8811    0
# Name: PSL23DDAY, dtype: int64
# PSL23RLAN
# 8811    2
# Name: PSL23RLAN, dtype: int64
# ***Issue merging SLDL:  24 and prec: 049-AGX ***
# PSL24DRUS
# 8820    1
# Name: PSL24DRUS, dtype: int64
# PSL24RMAN
# 8820    0
# Name: PSL24RMAN, dtype: int64

# %%
lost_sum = 0
for val in sorted(global_precinct_differences_dict.keys()):
    lost_sum += global_precinct_differences_dict[val]
    print(val, global_precinct_differences_dict[val])
# Out:
# PSL17DMIL 1
# PSL17RHAS 0
# PSL17RRUT 0
# PSL22DADH 0
# PSL22DLEL 2
# PSL22RSPE 0
# PSL23DDAY 0
# PSL23RLAN 2
# PSL24DRUS 17
# PSL24RMAN 1
# PSL25DJAM 1
# PSL25DJAR 8
# PSL25DJOS 1
# PSL25DMAK 1
# PSL25DNSI 2
# PSL25RBUR 0
# PSL26DCRA 7
# PSL49DWES 2
# PSL49RHAA 1
# PSL53DNOV 1
# PSL53RGUI 0
# PSL53RHAL 1
# PSL53RMUL 2
# PSL85RVIT 1
# PSL94DONE 5
# PSL94REDW 0

# %%
tot_sum = 0
for val in final_races:
    tot_sum += sum(attempt_one[val])
    print(val, sum(attempt_one[val]))
# Out:
# PSL01DTHE 4253
# PSL03DJOH 7243
# PSL05DWIN 3911
# PSL06DROB 10753
# PSL07DSWE 8082
# PSL08DSMI 11185
# PSL09DBOY 16008
# PSL09DSTO 2580
# PSL10DBUR 1355
# PSL10DUPC 6151
# PSL11DHOW 5760
# PSL12DBRE 10015
# PSL12DROS 2503
# PSL13DSKI 7628
# PSL14DSWE 7211
# PSL15DCRO 6014
# PSL16DROM 3839
# PSL16DSMI 9025
# PSL17DMIL 4558
# PSL18DBOG 11437
# PSL19DLIG 10916
# PSL20DBRO 7527
# PSL21DLIS 10834
# PSL22DADH 2680
# PSL22DLEL 10181
# PSL23DDAY 6172
# PSL24DRUS 11809
# PSL25DJAM 3202
# PSL25DJAR 6168
# PSL25DJOS 911
# PSL25DMAK 2353
# PSL25DNSI 1107
# PSL26DCRA 10649
# PSL27DBIT 8775
# PSL28DMIR 10026
# PSL31DKEL 10469
# PSL32DING 10200
# PSL32DWAS 1337
# PSL33DDEN 11004
# PSL33DGRA 3365
# PSL34DSYK 10789
# PSL35DGAL 5478
# PSL36DHAR 3294
# PSL36DSHA 6259
# PSL37DWEI 9612
# PSL38DCAM 7068
# PSL39DBLA 5478
# PSL39DHIC 826
# PSL39DJON 1646
# PSL40DJAC 5306
# PSL41DBER 7318
# PSL43DCOX 6664
# PSL45DSOB 5408
# PSL46DSHE 6533
# PSL47DLAR 6308
# PSL49DWES 5910
# PSL50DSIM 5460
# PSL52DHOR 5121
# PSL53DNOV 3695
# PSL54DSHO 6388
# PSL55DSTE 8862
# PSL56DMIL 10220
# PSL57DADK 6289
# PSL58DHAG 9840
# PSL59DSTA 8999
# PSL60DTRO 7679
# PSL61DDUD 7230
# PSL62DROS 4634
# PSL63DBLA 7936
# PSL63DLAN 1573
# PSL63DPRO 2879
# PSL64DOBR 8611
# PSL65DDAR 5396
# PSL67DMOR 9078
# PSL68DMOU 6385
# PSL69DBEH 7001
# PSL70DBAR 4727
# PSL71DCAR 6356
# PSL73DMCC 7202
# PSL75DCLI 8350
# PSL76DWES 6865
# PSL77DWIL 5271
# PSL78DOWE 4613
# PSL79DRIC 5723
# PSL84DMON 3305
# PSL86DROB 5021
# PSL87DBAR 3867
# PSL88DLIE 5473
# PSL89DMIL 7769
# PSL91DDAI 3225
# PSL92DWOR 4669
# PSL94DONE 5351
# PSL96DDIP 4359
# PSL96DOLI 5370
# PSL97DSWO 4139
# PSL98DBEE 4870
# PSL99DDAN 5836
# PSL01RWET 990
# PSL01RWIG 6924
# PSL02RJOH 7858
# PSL02RMAR 3474
# PSL03RGHA 5782
# PSL04RCUP 9420
# PSL05RGIN 6573
# PSL06RHAR 3095
# PSL06RHAW 3611
# PSL07RPAT 6561
# PSL09RRUS 1087
# PSL14RMCM 2770
# PSL15RKUS 2986
# PSL16RGRE 5353
# PSL17RHAS 1258
# PSL17RRUT 831
# PSL18RPAC 1117
# PSL19RFRE 4591
# PSL20RBAE 3348
# PSL21RCOO 4099
# PSL22RSPE 2520
# PSL23RLAN 4088
# PSL24RMAN 4385
# PSL25RBUR 1098
# PSL27RBRI 7574
# PSL28RMON 6589
# PSL29RABR 6494
# PSL30RSEI 7772
# PSL33RHIL 2261
# PSL34RTOD 1584
# PSL35RSAR 2282
# PSL36RYOU 4822
# PSL37RBIG 4200
# PSL38RROE 5333
# PSL39RMUL 889
# PSL40RPLU 6156
# PSL41RWHI 5947
# PSL42RSTU 2341
# PSL42RYOU 6644
# PSL43RCRE 5359
# PSL43RSMI 2817
# PSL44RMCM 1085
# PSL45RLOG 2183
# PSL46RSAL 2798
# PSL47RMER 5290
# PSL48ROEL 8453
# PSL49RHAA 3546
# PSL50RSTO 8240
# PSL51RCAR 5830
# PSL52RGRO 5382
# PSL52RWEL 4997
# PSL53RGUI 1360
# PSL53RHAL 3506
# PSL53RMUL 2999
# PSL54RZEL 9935
# PSL55RMAN 5737
# PSL56RLAC 3774
# PSL57RSTE 7554
# PSL58RSIM 2589
# PSL59RMAN 5917
# PSL60RPHI 6224
# PSL61RCAL 8887
# PSL62RLIP 9899
# PSL63RLOY 5545
# PSL64RYOD 4924
# PSL65RBLE 2113
# PSL65RDIL 5879
# PSL65RSCH 6197
# PSL66RBIR 4787
# PSL66RFRE 4199
# PSL66ROWE 4314
# PSL67RJOR 10976
# PSL68RCAR 12067
# PSL69RRAY 7679
# PSL70RKIC 6485
# PSL70RROB 3282
# PSL71RCLA 5374
# PSL71RFRA 5681
# PSL72RHOU 11142
# PSL73RBRO 4416
# PSL73RLAM 9579
# PSL74RDEA 10183
# PSL75RPAV 4602
# PSL76RGRE 7914
# PSL76RHAL 5180
# PSL77RLAR 7275
# PSL78RADA 924
# PSL78RMIT 2939
# PSL78RSTE 7820
# PSL79RKOE 6607
# PSL80RPOW 12471
# PSL81RHOO 11152
# PSL82RRIE 10984
# PSL83RCRO 12850
# PSL84RMAN 13284
# PSL85RVIT 11814
# PSL86RRIC 9762
# PSL87RMCC 12685
# PSL88RCLI 5555
# PSL88ROLL 3124
# PSL88RTHO 4789
# PSL89RSWE 5437
# PSL90RBAL 10493
# PSL91RWIL 7271
# PSL92RJOH 5411
# PSL93RHAL 5682
# PSL93RSTE 10177
# PSL94REDW 7895
# PSL95RJON 10919
# PSL96RFER 6734
# PSL97RHOL 7444
# PSL98RHIL 7582
# PSL99RFOW 7413
# PSL96LHER 18

# %%
lost_sum + tot_sum
# Out:
# 1276883

# %% [markdown]
# 1276883 total sum matches

# %% [markdown]
# ### Note: Checked these totals on 02/02/22 and they MATCH what the state has here: https://www.sos.state.oh.us/elections/election-results-and-data/

# %% [markdown]
# ## Add in a SL_DIST column

# %%
attempt_one["Tot_Votes"] = 0

for race in final_races:
    attempt_one["Tot_Votes"] += attempt_one[race]

# %%
def contains_sll(dist_list):
    #print("Calling on ", dist_list)
    for dist_tuple in dist_list:
        #print("Call on ", dist_tuple)
        if dist_tuple[0] == "SL":
            #print("Found the SLL")
            return dist_tuple[1]

# %%
check_list = {i:contains_sll(precinct_mapping_dict[i]) for i in precinct_mapping_dict.keys()}

# %%
attempt_one["SLDL_DIST"] = attempt_one["UNIQUE_ID"].map(check_list).fillna("n/a")
attempt_one["SLDL_DIST"].value_counts(dropna=False)
# Out:
# n/a    198
# 90     128
# 96     127
# 93     119
# 95     118
#       ...
# 15      71
# 35      70
# 71      68
# 01      67
# 17      61
# Name: SLDL_DIST, Length: 100, dtype: int64

# %%
attempt_one["SLDL_DIST"] = np.where((attempt_one["SLDL_DIST"]=="n/a") & (attempt_one["PRECINCT20"]!="ZZZ") & (attempt_one["Tot_Votes"] > 0),attempt_one["UNIQUE_ID"].str[-3:-1],attempt_one["SLDL_DIST"])
attempt_one["SLDL_DIST"].value_counts(dropna=False)
# Out:
# 90     129
# 96     127
# 93     120
# 95     119
# 59     113
#       ...
# 55      73
# 17      72
# 71      69
# 01      67
# n/a     19
# Name: SLDL_DIST, Length: 100, dtype: int64

# %% [markdown]
# ## Note: The 11 others don't have any votes

# %%
attempt_one.drop("_merge", axis = 1, inplace = True)

# %%
oh_sll_districts["SLDL_DIST"] = oh_sll_districts["SLDLST"]
oh_sll_districts = oh_sll_districts[oh_sll_districts["SLDL_DIST"]!="ZZ"]

# %%
filtered_results = attempt_one[attempt_one["SLDL_DIST"] != "n/a"].dissolve("SLDL_DIST")
filtered_results.reset_index(inplace=True, drop=False)

# %%
from matplotlib.lines import Line2D

def compare_geometries(gdf_1,gdf_2,left_gdf_name,right_gdf_name,join_col_name,area_threshold=.1):
    '''
    Function that joins to GeoDataFrames on a column and reports area differences row-by-row
    '''
    gdf_1 = gdf_1.to_crs(3857)
    gdf_2 = gdf_2.to_crs(3857)
    both = pd.merge(gdf_1,gdf_2,how="outer",on=join_col_name,validate="1:1",indicator=True)
    if(both["_merge"].str.contains("_")).any():
        print("Non-unique merge values")
        raise ValueError
    left_geoms = gp.GeoDataFrame(both,geometry="geometry_x")
    right_geoms = gp.GeoDataFrame(both,geometry="geometry_y")
    left_geoms["geometry_x"]=left_geoms.buffer(0)
    right_geoms["geometry_y"]=right_geoms.buffer(0)
    if (left_geoms.is_valid==False).any():
        raise ValueError
    elif(right_geoms.is_valid==False).any():
        raise ValueError
    count = 0
    area_list = []
    print("Checking " + str(both.shape[0])+" precincts for differences of greater than "+str(area_threshold)+" km^2")
    print()
    for index,row in both.iterrows():
        diff = left_geoms.iloc[[index]].symmetric_difference(right_geoms.iloc[[index]])
        intersection = left_geoms.iloc[[index]].intersection(right_geoms.iloc[[index]])
        area = float(diff.area/10e6)
        area_list.append(area)
        if (area > area_threshold):
            count += 1
            name = left_geoms.at[index,join_col_name]
            print(str(count)+") For " + name + " difference in area is " + str(area))
            if (intersection.iloc[0].is_empty):
                base = left_geoms.iloc[[index]].plot(color="orange",figsize=(10,10))
                right_geoms.iloc[[index]].plot(color="blue",ax=base)
                base.set_title(name)
                custom_lines = [Line2D([0], [0], color='green', lw=4),
                Line2D([0], [0], color='orange', lw=4),
                Line2D([0], [0], color='blue', lw=4)]
                base.legend(custom_lines, ['Overlap', left_gdf_name,right_gdf_name])
            else:
                base = left_geoms.iloc[[index]].plot(color="orange",figsize=(10,10))
                right_geoms.iloc[[index]].plot(color="blue",ax=base)
                intersection.plot(color="green",ax=base)
                base.set_title(name)
                custom_lines = [Line2D([0], [0], color='green', lw=4),
                Line2D([0], [0], color='orange', lw=4),
                Line2D([0], [0], color='blue', lw=4)]
                base.legend(custom_lines, ['Overlap', left_gdf_name,right_gdf_name])
                
                
    df = pd.DataFrame(area_list)
    print()
    print("Scroll down to see plots of any differences")
    print()
    print("Of the "+ str(both.shape[0])+" precincts:")
    print()
    print(str(len(df[df[0]==0]))+" precincts w/ a difference of 0 km^2")
    print(str(len(df[(df[0]<.1) & (df[0]>0)]))+ " precincts w/ a difference between 0 and .1 km^2")
    print(str(len(df[(df[0]<.5) & (df[0]>=.1)]))+ " precincts w/ a difference between .1 and .5 km^2")
    print(str(len(df[(df[0]<1) & (df[0]>=.5)]))+ " precincts w/ a difference between .5 and 1 km^2")
    print(str(len(df[(df[0]<2) & (df[0]>=1)]))+ " precincts w/ a difference between 1 and 2 km^2")
    print(str(len(df[(df[0]<5) & (df[0]>=2)]))+ " precincts w/ a difference between 2 and 5 km^2")
    print(str(len(df[(df[0]>=5)]))+ " precincts w/ a difference greater than 5 km^2")

# %%
compare_geometries(oh_sll_districts,filtered_results,"Official Map","Results Assigned","SLDL_DIST",area_threshold=.1)
# Out:
# Checking 99 precincts for differences of greater than 0.1 km^2
#
# 1) For 49 difference in area is 0.33363612333774983
# 2) For 79 difference in area is 0.4450829905614866
# 3) For 64 difference in area is 0.11119134799268872
# 4) For 20 difference in area is 0.29285112264827795
# 5) For 72 difference in area is 0.6169746132719164
# 6) For 84 difference in area is 0.22729244725217163
# 7) For 70 difference in area is 0.12905818581201667
# 8) For 23 difference in area is 0.17046667866917745
# 9) For 13 difference in area is 1.1681334096583145
# 10) For 82 difference in area is 0.1519055096347626
# 11) For 83 difference in area is 0.10340429253885673
# 12) For 51 difference in area is 0.15613231440484526
# 13) For 10 difference in area is 1.6614355144121975
# 14) For 08 difference in area is 0.38217343936205883
# 15) For 86 difference in area is 0.17225841200682965
# 16) For 48 difference in area is 0.3465862946343343
# 17) For 38 difference in area is 0.3748503318233492
# 18) For 39 difference in area is 0.11997469750299275
# 19) For 71 difference in area is 0.6169746132719162
# 20) For 76 difference in area is 5.558684306386967
# 21) For 88 difference in area is 2.701113283885595
# 22) For 85 difference in area is 0.17879123015626563
# /Users/peterhorton/opt/anaconda3/envs/geo_env/lib/python3.9/site-packages/geopandas/plotting.py:658: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=figsize)
# 23) For 24 difference in area is 0.16149231413910117
# 24) For 46 difference in area is 0.17699532349842045
# 25) For 17 difference in area is 0.41117794868616825
# 26) For 75 difference in area is 8.97748678651051
# 27) For 87 difference in area is 0.20603113424953617
# 28) For 43 difference in area is 2.2102261146100552
# 29) For 69 difference in area is 0.12905818581201667
# 30) For 40 difference in area is 2.158724183324824
# 31) For 19 difference in area is 0.12925698677534553
# 32) For 89 difference in area is 4.162675127829893
# 33) For 95 difference in area is 0.12441598770278293
# 34) For 74 difference in area is 0.5117366538973939
# 35) For 30 difference in area is 0.3814549768562415
# 36) For 52 difference in area is 0.39887286781577314
# 37) For 78 difference in area is 0.11898685002039226
# 38) For 53 difference in area is 0.39624658171773436
# 39) For 42 difference in area is 0.11554202097342878
# 40) For 99 difference in area is 0.15590285976273555
# 41) For 11 difference in area is 0.1500750926965547
# 42) For 32 difference in area is 0.36323537752155655
# 43) For 18 difference in area is 0.19630685354573407
# 44) For 44 difference in area is 1.034832822094615
# 45) For 41 difference in area is 0.14281939719746176
# 46) For 16 difference in area is 1.5650244794179573
#
# Scroll down to see plots of any differences
#
# Of the 99 precincts:
#
# 9 precincts w/ a difference of 0 km^2
# 44 precincts w/ a difference between 0 and .1 km^2
# 33 precincts w/ a difference between .1 and .5 km^2
# 3 precincts w/ a difference between .5 and 1 km^2
# 4 precincts w/ a difference between 1 and 2 km^2
# 4 precincts w/ a difference between 2 and 5 km^2
# 2 precincts w/ a difference greater than 5 km^2

# %% [markdown]
# ## Sort the columns to match what VEST has

# %%
attempt_one = attempt_one[["UNIQUE_ID","COUNTYFP",'STATEFP20', 'COUNTYFP20', 'VTDST20', 'PRECINCT20', 'GEOID20', 'NAME20',"SLDL_DIST"]+
                         final_races+["geometry"]]

# %%
if not os.path.exists('./oh_prim_20_prec/'):
    os.mkdir('./oh_prim_20_prec/')

attempt_one.to_file('./oh_prim_20_prec/oh_prim_20_sldl_prec.shp')
